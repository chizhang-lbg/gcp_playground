# %% [markdown]
# <br>
# <center><img src="https://gretel-public-website.s3.us-west-2.amazonaws.com/assets/brand/gretel_brand_wordmark.svg" alt="Gretel" width="350"/></center>
# <br>
#
#
# ## 👋 Welcome to the Gretel Synthetic PII Finance Multilingual Notebook!
# In this Notebook, we will explore the Gretel Synthetic PII Finance Multilingual dataset and demonstrate how to visualize and process the generated data containing PII spans.
# <br>
# <img src="https://cdn-uploads.huggingface.co/production/uploads/632ca8dcdbea00ca213d101a/nxKiabD9puCKhJCDciMto.webp" alt="Header" width="600"/>
#
#
# ## ✅ Set up your environment
# To get started, we will install the necessary dependencies and load the dataset from Hugging Face.
# * https://huggingface.co/datasets/gretelai/synthetic_pii_finance_multilingual
# <br>
#
# #### Ready? Let's go 🚀
#
# ## 💾 Install dependencies

# %%
# !pip install -Uqq spacy datasets
# Out:
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# google-colab 1.0.0 requires requests==2.31.0, but you have requests 2.32.3 which is incompatible.

# %% [markdown]
# ## 📊 Load and explore the dataset
# - Load the Gretel Synthetic PII Finance Multilingual dataset from Hugging Face as a DataFrame.
# - Explore the loaded dataset.

# %%
import ast
import random
from typing import Dict

import pandas as pd
from datasets import load_dataset
from spacy import displacy

# Load dataset from Huggingface as a Dataframe

df = pd.DataFrame(load_dataset("gretelai/synthetic_pii_finance_multilingual")['train'])
df
# Out:
#        level_0  index                      document_type  \
# 0        40012  40012  Supply Chain Management Agreement
# 1        46425  46425  Supply Chain Management Agreement
# 2         4689   4689         Real Estate Loan Agreement
# 3         3002   3002         Real Estate Loan Agreement
# 4        16187  16187                              Email
# ...        ...    ...                                ...
# 50341    44732  44732              Investment Prospectus
# 50342    54343  54343                       FIX Protocol
# 50343    38158  38158              Investment Prospectus
# 50344      860    860                   Loan Application
# 50345    15795  15795                                CSV
#
#                                     document_description  \
# 0      A legal contract outlining the terms and condi...
# 1      A legal contract outlining the terms and condi...
# 2      A legal contract outlining terms and condition...
# 3      A legal contract outlining terms and condition...
# 4      A communication sent electronically containing...
# ...                                                  ...
# 50341  A formal document detailing the objectives, ri...
# 50342  A messaging standard used for the electronic c...
# 50343  A formal document detailing the objectives, ri...
# 50344  A form capturing personal, financial, and empl...
# 50345  A simple, widely used file format for tabular ...
#
#                                            expanded_type  \
# 0                             Vendor Management Contract
# 1                      Supply Chain Resilience Framework
# 2      International Real Estate Investment Loan Agre...
# 3                      Commercial Property Loan Contract
# 4                                             Invitation
# ...                                                  ...
# 50341                                Fashion and Apparel
# 50342                       MarketDataIncrementalRefresh
# 50343                             Travel and Hospitality
# 50344                            Debt Consolidation Plan
# 50345                                       Standardized
#
#                                     expanded_description language  \
# 0      This subtype involves the contractual agreemen...  English
# 1      This subtype details the framework for buildin...  English
# 2      This subtype encompasses loans for internation...  Spanish
# 3      This subtype focuses on loans for commercial r...  Italian
# 4      Create an email inviting recipients to an even...   France
# ...                                                  ...      ...
# 50341  Prepare a detailed overview of investment pros...  English
# 50342  Develop a MarketDataIncrementalRefresh message...  English
# 50343  Construct a comprehensive overview of investme...  English
# 50344  Evaluate the potential for debt consolidation ...   German
# 50345  Standardize the subtype according to industry ...  Spanish
#
#                                     language_description   domain  \
# 0      English language as spoken in the United State...  finance
# 1      English language as spoken in the United State...  finance
# 2          Spanish language as spoken in Spain or Mexico  finance
# 3                    Italian language as spoken in Italy  finance
# 4                    French language as spoken in France  finance
# ...                                                  ...      ...
# 50341  English language as spoken in the United State...  finance
# 50342  English language as spoken in the United State...  finance
# 50343  English language as spoken in the United State...  finance
# 50344               German language as spoken in Germany  finance
# 50345      Spanish language as spoken in Spain or Mexico  finance
#
#                                           generated_text  \
# 0      SUPPLY CHAIN MANAGEMENT AGREEMENT\n\nThis Supp...
# 1      SUPPLY CHAIN RESILIENCE FRAMEWORK\n\nThis Supp...
# 2      CONTRATO DE PRÉSTAMO PARA INVERSIÓN INMOBILIAR...
# 3      REPUBBLICA ITALIANA\n\nCONTRATTO DI PRESTITO I...
# 4      Subject: Invitation à notre soirée de lancemen...
# ...                                                  ...
# 50341  INVESTMENT PROSPECTUS\n\nINTRODUCTION\n\nWe ar...
# 50342  MDReqID:123456\nSubscriptionRequestType:0\nMar...
# 50343  **Patrizio Gaito-Mascagni's Travel and Hospita...
# 50344  **Kreditantrag: Debt Consolidation Plan**\n\nS...
# 50345  "ID","Nombre","Edad","País","Salario"\n"1","Ma...
#
#                                                pii_spans  conformance_score  \
# 0      [{"start": 119, "end": 141, "label": "date"}, ...                 85
# 1      [{"start": 119, "end": 142, "label": "date"}, ...                 92
# 2      [{"start": 182, "end": 209, "label": "street_a...                 85
# 3      [{"start": 85, "end": 103, "label": "name"}, {...                 85
# 4      [{"start": 202, "end": 207, "label": "time"}, ...                 85
# ...                                                  ...                ...
# 50341  [{"start": 98, "end": 122, "label": "company"}...                 90
# 50342  [{"start": 384, "end": 396, "label": "name"}, ...                 92
# 50343  [{"start": 2, "end": 25, "label": "name"}, {"s...                 85
# 50344  [{"start": 346, "end": 363, "label": "name"}, ...                 85
# 50345  [{"start": 43, "end": 58, "label": "name"}, {"...                 85
#
#        quality_score  toxicity_score  bias_score  groundedness_score
# 0                 90               5          15                  95
# 1                 87               5          12                  95
# 2                 90               5          15                  95
# 3                 90               5          10                  95
# 4                 90               5          15                  95
# ...              ...             ...         ...                 ...
# 50341             85               5          10                  95
# 50342             85               5          12                  88
# 50343             90               5          15                  95
# 50344             90               5          10                  95
# 50345             90               5          10                  95
#
# [50346 rows x 16 columns]

# %% [markdown]
# ## 🔍 Visualize PII entities
# - Define a helper function to visualize PII entities in the generated data using a Displacy-like style.
# - Select a random English record from the dataset and visualize its PII entities.

# %%
# Helper function to visualize entities in Displacy-like style

def visualize_entities(record: Dict) -> None:
    """
    Visualize the entities in the generated data using a predefined set of PII spans.
    Args:
        record: A dictionary containing the generated data and PII spans.
    """
    colors = [
        "#FFB3BA", "#FFDFBA", "#FFFFBA", "#BAFFC9", "#BAE1FF",
        "#D7BDE2", "#FAD7A0", "#D5F5E3", "#AED6F1", "#F9E79F",
        "#F5CBA7", "#D2B4DE", "#A9CCE3", "#FADBD8", "#D4E6F1",
        "#E6B0AA", "#F9E79F", "#A3E4D7", "#D7DBDD", "#F7DC6F",
        "#F1948A", "#C39BD3", "#7FB3D5", "#76D7C4", "#F0B27A",
        "#E59866", "#AF7AC5", "#5499C7", "#48C9B0"
    ]
    num_colors = len(colors)
    text = record["generated_text"]
    spans = ast.literal_eval(record["pii_spans"]) if isinstance(record["pii_spans"], str) else record["pii_spans"]
    doc = {"text": text, "ents": [], "title": None}
    for i, span in enumerate(spans):
        start, end, label = span["start"], span["end"], span["label"]
        color = colors[i % num_colors]
        doc["ents"].append({"start": start, "end": end, "label": label, "color": color})
    options = {
        "ents": [span["label"] for span in spans],
        "colors": {label: colors[i % num_colors] for i, label in enumerate(set(span["label"] for span in spans))},
        "compact": True,
    }
    displacy.render(doc, style="ent", manual=True, jupyter=True, options=options)

# Select a random index from the filtered DataFrame
random_index = random.randint(0, len(df.query("language == 'English'")) - 1)

# Select the record at the random index
record = df.query("language == 'English'").iloc[random_index]

# Visualize the entities
visualize_entities(record)
# Out:
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">MDReqID:123456<br>SubscriptionRequestType:0<br>MarketDepth:0<br>MDUpdateType:0<br>Aggregated:0<br>NoMDEntryTypes:0<br>NoRelatedSym:0<br> MarketSegmentID:EQUITIES<br>Symbol:XYZ<br>SymbolSfx:<br>SecurityID:<br>IDSource:<br>SecurityType:<br>SecuritySubType:<br>TradingSessionID:PRE<br>TradingSessionSubID:PRE_OPEN<br>UnsolicitedIndicator:0<br>MDReqID:123456<br>SubscriptionRequestType:0<br>MarketDepth:0<br>MDUpdateType:0<br>Aggregated:0<br>NoMDEntryTypes:0<br>NoRelatedSym:0<br> MarketSegmentID:EQUITIES<br>Symbol:XYZ<br>SymbolSfx:<br>SecurityID:<br>IDSource:<br>SecurityType:<br>SecuritySubType:<br>TradingSessionID:PRE<br>TradingSessionSubID:PRE_OPEN<br>UnsolicitedIndicator:0<br> ClOrdID:
# <mark class="entity" style="background: #FFFFBA; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     CID-96323
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">customer_id</span>
# </mark>
# <br>TransactTime:20220302-12:30:45<br>OrdType:2<br>Price:50.50<br>Side:1<br>Text:'
# <mark class="entity" style="background: #FFDFBA; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Deanna Riggs-Doyle
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">name</span>
# </mark>
# '<br>EncodedText:<br>TransactTime:20220302-12:30:45<br>OrdType:2<br>Price:50.50<br>Side:1<br>ClOrdLinkID:'
# <mark class="entity" style="background: #FFB3BA; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     231132
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">account_pin</span>
# </mark>
# '<br>Text:<br>EncodedText:<br>TradeReportID:<br>LastPx:50.50<br>LastQty:100<br>LastCapacity:1<br>LeavesQty:0<br>ClearingFirm:<br>ClearingAccount:<br>ClientID:<br>TradeOriginationDate:<br>TradeOriginationTime:<br>TradeInputSource:<br>TradeInputDevice:<br>SecurityDesc:<br>SecurityExchange:<br>TradeDate:<br>TransactTime:20220302-12:30:45<br>OrdType:2<br>Price:50.50<br>Side:1<br>ClOrdLinkID:'
# <mark class="entity" style="background: #FFB3BA; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     231132
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">account_pin</span>
# </mark>
# '<br>Text:'
# <mark class="entity" style="background: #FFDFBA; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Deanna Riggs-Doyle
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">name</span>
# </mark>
# '<br></div></span>

# %% [markdown]
# ## 📝 Process and markup PII
# - Define functions to process a single record and output marked-up text with labeled PII.
# - Show a random record with marked-up PII.
# - Apply processing to all records and create a new 'marked_up_text' column in the DataFrame.

# %%
# Function to process a single record and output marked-up text
def process_record(record: Dict) -> str:
    text = record['generated_text']
    spans = ast.literal_eval(record['pii_spans'])
    # Sort spans by start index in descending order
    spans = sorted(spans, key=lambda x: x['start'], reverse=True)
    for span in spans:
        start, end, label = span['start'], span['end'], span['label']
        value = text[start:end]
        # Insert the marked-up PII value into the text
        text = text[:start] + f"{{[{label}]{value}}}" + text[end:]
    return text

# Function to show a random record
def show_random_record(language: str = 'English') -> None:
    # Select a random index from the filtered DataFrame
    random_index = random.randint(0, len(df.query(f"language == '{language}'")) - 1)
    # Select the record at the random index
    record = df.query(f"language == '{language}'").iloc[random_index]
    # Process the record and print the marked-up text
    marked_up_text = process_record(record)
    print(marked_up_text)

# Function to apply processing to all records and create a new column
def process_all_records(language: str = 'English') -> pd.DataFrame:
    # Filter the DataFrame by language
    filtered_df = df.query(f"language == '{language}'")
    # Apply the process_record function to each record and create a new column
    filtered_df['marked_up_text'] = filtered_df.apply(process_record, axis=1)
    return filtered_df

# Markup Text using the format {[PII Label]PII Value}
show_random_record()

# Add a 'marked_up_text' column to the DataFrame containing the labeled PII for each row
labeled_dataset = process_all_records()
labeled_dataset
# Out:
# **{[company]Technology and Innovation Fund}**
#
# **Investment Prospectus**
#
# **Introduction**
#
# The {[company]Technology and Innovation Fund} is a specialized investment vehicle focused on identifying and capitalizing on disruptive technologies and innovative companies. Our objective is to provide investors with long-term capital appreciation by investing in a diversified portfolio of technology and innovation-driven companies.
#
# **Fund Objectives**
#
# Our primary objective is to achieve capital growth by investing in a diversified portfolio of technology and innovation-driven companies. We aim to identify opportunities in sectors such as artificial intelligence, biotechnology, clean energy, and digital transformation.
#
# **Investment Strategy**
#
# Our investment strategy is based on rigorous research and analysis. We seek to identify companies with a sustainable competitive advantage, a strong management team, and a clear path to profitability. We employ a disciplined approach to portfolio construction, focusing on risk management and diversification.
#
# **Risks**
#
# Investing in technology and innovation-driven companies involves significant risks. These risks include market risk, technology risk, and company-specific risk. We manage these risks through diversification, rigorous research, and active portfolio management.
#
# **Past Performance**
#
# Past performance is not indicative of future results. However, we are proud of our track record. Over {[date]the past five years}, our fund has delivered an average {[date]annual} return of 23.5%. This performance has been driven by our focus on disruptive technologies and innovative companies.
#
# **Investment Opportunities**
#
# We are currently investing in a number of exciting opportunities. These include:
#
# - **AI Medical**: A healthcare technology company developing artificial intelligence-powered diagnostic tools.
# - **{[company]EcoPower}**: A clean energy company specializing in solar power technology.
# - **DataMate**: A software company providing data analytics solutions for businesses.
#
# **Contact Information**
#
# For more information about the {[company]Technology and Innovation Fund}, please contact our Investor Relations team at:
#
# {[name]Aimée Petitjean}
# Investor Relations Manager
# {[street_address]2677 Holden Ridge Apt. 268}
# Credit Card Security Code: {[credit_card_security_code]705}
#
# **Important Notice**
#
# This prospectus is for informational purposes only and does not constitute an offer to sell or a solicitation of an offer to buy any secur
# <ipython-input-22-ee2625fefb9c>:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered_df['marked_up_text'] = filtered_df.apply(process_record, axis=1)
#        level_0  index                        document_type  \
# 0        40012  40012    Supply Chain Management Agreement
# 1        46425  46425    Supply Chain Management Agreement
# 5        32489  32489                        SWIFT Message
# 6        51960  51960          Health Insurance Claim Form
# 8        44856  44856  Customer support conversational log
# ...        ...    ...                                  ...
# 50338     6265   6265            Financial Aid Application
# 50339    54886  54886         Product Disclosure Statement
# 50341    44732  44732                Investment Prospectus
# 50342    54343  54343                         FIX Protocol
# 50343    38158  38158                Investment Prospectus
#
#                                     document_description  \
# 0      A legal contract outlining the terms and condi...
# 1      A legal contract outlining the terms and condi...
# 5      A message format used by banks and financial i...
# 6      A form capturing details of a health insurance...
# 8      A log file capturing customer support interact...
# ...                                                  ...
# 50338  A form submitted by individuals to request fin...
# 50339  A document providing details about a financial...
# 50341  A formal document detailing the objectives, ri...
# 50342  A messaging standard used for the electronic c...
# 50343  A formal document detailing the objectives, ri...
#
#                            expanded_type  \
# 0             Vendor Management Contract
# 1      Supply Chain Resilience Framework
# 5                                  MT202
# 6                      Dental Care Claim
# 8                        Warranty Claims
# ...                                  ...
# 50338        Education Grant Application
# 50339       Retail Investment Disclosure
# 50341                Fashion and Apparel
# 50342       MarketDataIncrementalRefresh
# 50343             Travel and Hospitality
#
#                                     expanded_description language  \
# 0      This subtype involves the contractual agreemen...  English
# 1      This subtype details the framework for buildin...  English
# 5      Generate a synthetic MT202 message, including ...  English
# 6      Produce a synthetic data point for a dental ca...  English
# 8      Outline the process for assisting customers wi...  English
# ...                                                  ...      ...
# 50338  Fill out the education grant application form,...  English
# 50339  This subtype covers retail sector investments,...  English
# 50341  Prepare a detailed overview of investment pros...  English
# 50342  Develop a MarketDataIncrementalRefresh message...  English
# 50343  Construct a comprehensive overview of investme...  English
#
#                                     language_description   domain  \
# 0      English language as spoken in the United State...  finance
# 1      English language as spoken in the United State...  finance
# 5      English language as spoken in the United State...  finance
# 6      English language as spoken in the United State...  finance
# 8      English language as spoken in the United State...  finance
# ...                                                  ...      ...
# 50338   English language as spoken in the United Kingdom  finance
# 50339  English language as spoken in the United State...  finance
# 50341  English language as spoken in the United State...  finance
# 50342  English language as spoken in the United State...  finance
# 50343  English language as spoken in the United State...  finance
#
#                                           generated_text  \
# 0      SUPPLY CHAIN MANAGEMENT AGREEMENT\n\nThis Supp...
# 1      SUPPLY CHAIN RESILIENCE FRAMEWORK\n\nThis Supp...
# 5      :20:OOFFF**222/987\n:25:USA\n:20C:USD150000,00...
# 6      Patient Information\n\n* Full Name: Eufemia Go...
# 8      ----------------------------------------------...
# ...                                                  ...
# 50338  Financial Aid Application - Education Grant\n\...
# 50339  PRODUCT DISCLOSURE STATEMENT\n\nInvestment in ...
# 50341  INVESTMENT PROSPECTUS\n\nINTRODUCTION\n\nWe ar...
# 50342  MDReqID:123456\nSubscriptionRequestType:0\nMar...
# 50343  **Patrizio Gaito-Mascagni's Travel and Hospita...
#
#                                                pii_spans  conformance_score  \
# 0      [{"start": 119, "end": 141, "label": "date"}, ...                 85
# 1      [{"start": 119, "end": 142, "label": "date"}, ...                 92
# 5      [{"start": 98, "end": 109, "label": "name"}, {...                 85
# 6      [{"start": 34, "end": 56, "label": "name"}, {"...                 85
# 8      [{"start": 323, "end": 333, "label": "customer...                 85
# ...                                                  ...                ...
# 50338  [{"start": 56, "end": 64, "label": "name"}, {"...                 85
# 50339  [{"start": 49, "end": 74, "label": "company"},...                 95
# 50341  [{"start": 98, "end": 122, "label": "company"}...                 90
# 50342  [{"start": 384, "end": 396, "label": "name"}, ...                 92
# 50343  [{"start": 2, "end": 25, "label": "name"}, {"s...                 85
#
#        quality_score  toxicity_score  bias_score  groundedness_score  \
# 0                 90               5          15                  95
# 1                 87               5          12                  95
# 5                 90               5          10                  80
# 6                 90               5          15                  95
# 8                 90               5          10                  95
# ...              ...             ...         ...                 ...
# 50338             90               5          10                  95
# 50339             85              10          15                  90
# 50341             85               5          10                  95
# 50342             85               5          12                  88
# 50343             90               5          15                  95
#
#                                           marked_up_text
# 0      SUPPLY CHAIN MANAGEMENT AGREEMENT\n\nThis Supp...
# 1      SUPPLY CHAIN RESILIENCE FRAMEWORK\n\nThis Supp...
# 5      :20:OOFFF**222/987\n:25:USA\n:20C:USD150000,00...
# 6      Patient Information\n\n* Full Name: {[name]Euf...
# 8      ----------------------------------------------...
# ...                                                  ...
# 50338  Financial Aid Application - Education Grant\n\...
# 50339  PRODUCT DISCLOSURE STATEMENT\n\nInvestment in ...
# 50341  INVESTMENT PROSPECTUS\n\nINTRODUCTION\n\nWe ar...
# 50342  MDReqID:123456\nSubscriptionRequestType:0\nMar...
# 50343  **{[name]Patrizio Gaito-Mascagni}'s Travel and...
#
# [25948 rows x 17 columns]
