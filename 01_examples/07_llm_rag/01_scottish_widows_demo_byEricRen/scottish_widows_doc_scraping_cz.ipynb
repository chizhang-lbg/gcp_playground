# %% [markdown]
# # Scottish Widows Document Scraping
#
# For the literature library search:
# https://adviser.scottishwidows.co.uk/literature-library.html
#
# For specific searching cirteria, for example *guides*:
# https://adviser.scottishwidows.co.uk/literature-library.html?n=1000&filter=swe:literaturelibrary/contenttype/guides

# %%
# !pip install --quiet PyPDF2
# !pip install --quiet pycryptodome
# Out:
# Collecting pycryptodome
#   Downloading pycryptodome-3.20.0-cp35-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (3.4 kB)
# Downloading pycryptodome-3.20.0-cp35-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (2.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.1/2.1 MB 57.9 MB/s eta 0:00:00:00:01
# Installing collected packages: pycryptodome
# Successfully installed pycryptodome-3.20.0

# %%
# Automatically restart kernel after installs so that your environment can access the new packages
import IPython

app = IPython.Application.instance()
app.kernel.do_shutdown(True)
# Out:
# {'status': 'ok', 'restart': True}

# %%
import io, os
from urllib.parse import urlparse

import pandas as pd
import requests
from bs4 import BeautifulSoup
from tqdm.notebook import tqdm
import PyPDF2


pd.options.display.max_rows = 100
pd.options.display.max_columns = 100

# %% [markdown]
# ## PDF Content Extraction

# %%
# Using pypdf2 to read a pdf uri

pdf_url = "https://adviser.scottishwidows.co.uk/assets/literature/docs/42365.pdf"
#pdf_url = "https://adviser.scottishwidows.co.uk//assets/literature/docs/27316.pdf"

response = requests.get(url=pdf_url)

assert response.status_code == requests.codes.ok


pdf_reader = PyPDF2.PdfReader( io.BytesIO(response.content) )

print(f"Total pages: {len(pdf_reader.pages)}")

for i, page in enumerate(pdf_reader.pages):
    page_text = page.extract_text()
    print(f"Page {i+1}: {page_text}")
# Out:
# Total pages: 3
# Page 1:
#
#
# Which trust form should I use?
#
# For life assurance (i.e. non pension) contracts which are already set up and on risk, Scottish Widows
# currently offers a choice of four trusts. To help you choose which trust is most appropriate for your
# needs, a brief description of each trust and where i t may be used is given below.
#
# Placing a policy under trust usually means you are giving up all rights to the benefits under a policy,
# although, in a few very specific situations it ’s possible to retain certain benefits and our range of
# trusts takes this  into account.
#
# Rememb er a trust is a legal document.  If you ’re in any doubt as to which trust is most suitable
# for your policy and your requirements, please seek advice from your financial or legal
# adviser.
#
# If your policy is a regular premium policy it may be what is known as a “qualifying policy”.
# Placing a qualifying policy under trust can have tax implications and advice should always be
# sought before considering a trust for this type of policy.
#
#
# 1. The Flexible Gift Trust  is suitable for a policy, without critical/terminal illness cover, which is
# owned by either one person or jointly by two people. It ’s normally not suitable for jointly -owned
# policies, where death benefits are payable on the death of t he first to die.  The wording of the
# Flexible Gif t Trust gives the trustees the ability to choose who will benefit from the trust from a
# given list of possible beneficiaries. You, as the original policy owner(s) are excluded as a
# possible beneficiary and therefore would n’t have access to any policy proce eds. You are giving
# up all your rights to the proceeds under the policy .
#
# 2. The Flexible Power of Appointment Trust  has been designed specifically for use with life
# assurance policies where the policy includes critical illness and/or terminal illness cover.
# Normally it ’s not possible for the original owner of a policy which is placed under trust  to benefit
# from the tru st funds.  However, where critical/terminal illness cover forms part of the policy
# benefits, it will often be important that money is available to you if you become ill . This  trust is
# designed to cover the situation by allowing the benefits to be paid to yo u, only in very specific
# circumstances, whilst maintaining the inheritance tax  (IHT)  positio n of the trust. (D etails of the
# specific situations where payout could occur and of the illnesses covered are in the policy
# provisions for your contract .)
#
# 3. The Reve rt to Settlor  trust is a version of the Flexible Gift Trust which can be used with policies
# that have a maturity date . This will generally be policies with a regular premium which are set up
# to run for a specific period (such as the Regular Savings Plan). Using this type of trust ensures
# policy benefits will revert to the original owner if living at the maturity date of the policy (or if the
# original policy owner becomes critically ill and critical illness benefits become payable) but will
# not form part of the settlor's taxable estate for IHT purposes if he dies beforehand.
#
# All of our flexible trusts (including the Revert to Settlor Trust) are discretionary in nature. This means
# the trustees use their discretion when deciding who ultimately benefits from th e trust capital. Gifts
# made into this type of trust are chargeable lifetime transfers for IHT purposes (unless exempt). This
# means an IHT charge may apply when the trust is created. IHT charges and reporting requirements
# may also arise at each tenth annive rsary, and when capital exits the trust (such as where trust capital
# is distributed to a beneficiary). Note, however, charges will generally only apply if the value of your
# gift (or the value of the trust fund ) is above the nil rate band ( this normally inc reases on 6th April each
# year, although is currently ‘frozen’ at £325,000 until April 2021). Protection policies, e.g. a Level Term
# Assurance, do n’t normally have a value unless a life assured is in poor health.
#
#
# Page 2:
#
#
# 4. The Gift trust (creating fixed interests) is what is often known as an absolute trust.  An
# absolute trust is one where you name specific beneficiaries to receive the benefits held under the
# trust. Once the trust has been set up you normally can ’t alter who the  beneficiaries are, even if
# your circumstances change.
#
#
# An absolute trust is treated differently from a flexible trust in that there will not be an immediate IHT
# charge  when the trust is created. Instead, you ’ll make a potentially exempt transfer which wi ll only
# become chargeable in the event of your death within seven  years of making the gift. As the gift is
# made absolutely to the beneficiaries, the trust fund will form part of the beneficiaries' estates for IHT
# and other purposes (such as divorce, bankru ptcy, financial means assessments). This means
# although IHT charges will not apply periodically or when capital leaves the trust, an IHT charge could
# apply on the death of a beneficiary.
#
#
# Glossary
#
# Absolute Trust – An absolute trust is a trust where the beneficiaries are known individuals and the
# contract is held by the trustees for those individual's benefit absolutely. Under this type of trust, all
# beneficiaries must be identified and named at outset and you cannot subsequently change a
# beneficiary or t he share in which they benefit.
#
# Critical Illness Cover – This type of cover will pay out a lump sum if you are diagnosed with a
# critical illness within the benefit term. We only cover the critical illnesses we define in our policy
# provisions.
#
# Fixed Inter est Trust – This is another name for an Absolute Trust.
#
# Flexible Trust - Under a flexible trust the trustees hold the trust property for any one or more of a
# wide class of beneficiaries as defined in the trust document. It ’s usually possible to add to or  exclude
# beneficiaries from the beneficial class either at outset or at some later point. The trustees can use
# their discretion when distributing the trust assets to the beneficiaries.
#
# Inheritance Tax  (IHT)  - This is the tax that is paid on your estate when you die if your assets are
# worth more than a set amount at the time of your death ( this is known as the nil rate band which
# normally increases on 6th April each year, although is currently ‘frozen’ at £325,000 until April 20 21).
# Broadly speaking your estate is everything you own at the time of your death, once your debts have
# been taken into account. IHT is also sometimes payable on assets you may have given away during
# your lifetime.
#
# Qualifying Policy –   A qualifying policy is a life insurance policy with a special tax status which
# means that when it comes to an end the proceeds are not usually subject to additional income tax or
# capital gains tax. Qualifying policies must meet specific conditions with regards to level of life c over,
# premium levels and regularity and policy term.
#
# Terminal Illness Cover – This is cover that provides a lump sum payment if you ’re diagnosed with
# an illness which is expected to cause your death within 12 months or before the end of the benefit
# term if shorter. Your policy provisions will provide more detail
#
# The Trustee(s)  The persons you appoint to look after the trust fund. The settlor will normally be one
# of the trustees. The Trustees become the legal owners of any property put in trust, but are o bliged by
# law to use the property for purposes that the settlor specifies in the trust deed.
#
#
#
# Page 3:
#
#
# Please tick one of the boxes below to indicate which trust form you ’d like  us to send you.
#
#  Flexible Gift Trust  ( 51082 )
#
#  Gift Trust (creating fixed interest) ( 51080 )
#
#  Flexible Power of Appointment Trust (SW56399)
#
#  Revert to Settlor Trust  (SW58105)
#
#
#
#
#
# Please write  your details below so we can send the trust form to you.
#
# Name:         Policy n umber :
#
# Address:
#
#
#
#
#
#
# Please return  this form to:  Scottish Widows , 15 Da lkeith Road, Edinburgh EH16 5BU
#
# Telephone number    03457 166 777
#
#
#
#
#
# Important - please read carefully
#
# The information given in this letter  is based on our understanding of UK law and HM Revenue &
# Customs  practice at the time of printing. We accept no liability for the accura cy of the information
# provided. Legislation  regarding taxation and HM Revenue & Customs practice may be subject to
# chan ge, which cannot be foreseen.
#
# Trust s are document s with legal significance that may affect the rights,  obligations and tax position of
# yourself and the beneficiaries. You should not proceed unless you are satisfied that  you understand
# its effect and that it achieves your objectives. If you have any dou bts or uncertainties you should
# seek independent legal advice.
#
# Special consideration may be required where you are either resident or domiciled outside the UK.
#
#
#
#
#
#
# Scottish Widows Limited. Registered in  England and Wales No. 3196171. Registered office in the United Kingdom at 25
# Gresham Street, London EC2V 7HN. Authorised by the Prudential Regulation Authority and regulated by the Financial
# Conduct Authority and the Prudential Regulation Authority. Finan cial Services Register number 181655.
#
# 42365 05/18

# %%
def get_pdf_pages(pdf_url):
    """Extract content of a pdf file page by page and return in a DataFrame with page_number and page_text columns"""
    
    url_parsed = urlparse(pdf_url)
    if url_parsed.scheme in ('file', ''): # possibly a local file
        assert os.path.exists(url_parsed.path)
        pdf_file = url_parsed.path
    else: # possibly a remote url, need to fetch it first
        response = requests.get(url=pdf_url)
        assert response.status_code == requests.codes.ok
        pdf_file = io.BytesIO(response.content)

    pdf_reader = PyPDF2.PdfReader( pdf_file )
        
    return pd.DataFrame([
            {"page_number": i+1, "page_text": page.extract_text()} 
            for i, page in enumerate(pdf_reader.pages)
        ])

# %%
# local_file = "../data/56036.pdf"
# df = get_pdf_pages(local_file)

df = get_pdf_pages(pdf_url)

df.head()
# Out:
#    page_number                                          page_text
# 0            1   \n \n \nWhich trust form should I use?  \n \n...
# 1            2   \n \n \n4. The Gift trust (creating fixed int...
# 2            3   \n \n \nPlease tick one of the boxes below to...

# %% [markdown]
# ## Search the literature library

# %%
# single pdf
# https://adviser.scottishwidows.co.uk/literature-library.html?filter=swe:literaturelibrary/contenttype/guides#search

# search default: 10 itmes in a page 
search_url = "https://adviser.scottishwidows.co.uk/literature-library.html?filter=swe:literaturelibrary/contenttype/guides#search"

# search and display all with number of items set to 1000
search_url = "https://adviser.scottishwidows.co.uk/literature-library.html?n=1000&filter=swe:literaturelibrary/contenttype/guides"

# %%
search_response = requests.get(url=search_url)

soup = BeautifulSoup(search_response.content, "html.parser")

#search_response.content
print(soup.title)
# Out:
# <title>Literature | For Advisers | Scottish Widows</title>

# %% [markdown]
# ### All the links in a page

# %%
print(soup.title.string)

# all links in the page
nb_links = len(soup.find_all('a'))
print(f"There are {nb_links} links in this page.\n")

# text from the page
#print(soup.get_text())

_ = [print(a) for a in soup.find_all('a')]
# Out:
# Literature | For Advisers | Scottish Widows
# There are 574 links in this page.
#
# <a href="https://www.scottishwidows.co.uk/" target="_self">visit our personal site</a>
# <a aria-label="Continue to our website" class="positive btn btn-primary" href="#">
# <span class="btn-text">Continue to our website</span>
# </a>
# <a accesskey="0" data-selector="skip-link-item-c_122_masthead_copy" data-tealium-event="Internal Click" data-tealium-narrative="Accessibility statement [Accesskey '0']" href="/accessibility.html">
# <span class="btn-text">Accessibility statement [Accesskey '0']</span>
# <span class="sr-only">Go to Accessibility statement</span>
# </a>
# <a accesskey="S" data-selector="skip-link-item-c_122_masthead_copy" data-tealium-event="Internal Click" data-tealium-narrative="Skip to Content [Accesskey 'S']" href="#main">
# <span class="btn-text">Skip to Content [Accesskey 'S']</span>
# <span class="sr-only">Skip to main content</span>
# </a>
# <a accesskey="N" data-selector="skip-link-item-c_122_masthead_copy" data-tealium-event="Internal Click" data-tealium-narrative="Skip to site Navigation [Accesskey 'N']" href="#mainnav">
# <span class="btn-text">Skip to site Navigation [Accesskey 'N']</span>
# <span class="sr-only">Go to Navigation</span>
# </a>
# <a accesskey="1" data-selector="skip-link-item-c_122_masthead_copy" data-tealium-event="Internal Click" data-tealium-narrative="Go to Home page [Accesskey '1']" href="/content/scottish-widows/extranet/en-gb.html">
# <span class="btn-text">Go to Home page [Accesskey '1']</span>
# <span class="sr-only">Go to Home Page</span>
# </a>
# <a accesskey="2" data-selector="skip-link-item-c_122_masthead_copy" data-tealium-event="Internal Click" data-tealium-narrative="Go to Sitemap [Accesskey '2']" href="/sitemap.html">
# <span class="btn-text">Go to Sitemap [Accesskey '2']</span>
# <span class="sr-only">Go to Sitemap</span>
# </a>
# <a data-selector="logo-anchor" data-tealium-event="Internal Click" href="/content/scottish-widows/extranet/en-gb.html" itemprop="url">
# <div class="icon-container">
# <div class="shape-container">
# <icon class="icon" data-selector="icon-sw_logo" data-svg-path="/assets/logo/sw_logo.svg" itemprop="logo"><svg aria-hidden="true" focusable="false" height="41px" version="1.1" viewbox="0 0 207 41" width="207px" xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink">
# <g fill="none" fill-rule="evenodd" stroke="none" stroke-width="1">
# <g transform="translate(-350.000000, -454.000000)">
# <g transform="translate(160.000000, 228.000000)">
# <g transform="translate(160.000000, 152.000000)">
# <g transform="translate(0.000000, 48.000000)">
# <g transform="translate(30.000000, 26.000000)">
# <path d="M193.103341,0.0757608696 C181.472974,6.76054348 169.088664,11.7072826 155.258922,11.1056522 C145.582565,10.6243478 136.642306,8.405 127.309461,6.78282609 C121.152996,5.70434783 114.99653,7.20173913 110.205194,11.4042391 L107.809526,13.5656522 L107.666767,13.5656522 C114.264892,6.12326087 123.057931,3.2398913 132.390776,4.1401087 L137.521164,4.79967391 L150.373901,7.02793478 C161.366315,8.81054348 173.973685,8.4673913 184.140776,4.08663043 C187.196935,2.91242588 190.176851,1.54905759 193.06319,0.00445652174 L193.103341,0.0757608696 Z" fill="#D3292E"></path>
# <path d="M97.9413362,28.3211957 C93.1053879,33.3615217 87.4842672,36.9044565 81.1805819,37.925 C71.8120474,39.3644565 62.8896336,36.3652174 53.8155388,35.046087 C43.8492026,33.303587 32.754181,32.7643478 23.0332112,35.5273913 C18.1983842,36.8035121 13.5153266,38.5964752 9.06517241,40.8752174 C8.91795259,40.8172826 8.96256466,40.8752174 8.96256466,40.7415217 L12.1880172,39.061413 C23.135819,33.5977174 34.6635776,29.8765217 47.6144612,30.656413 C52.2936213,30.9189714 56.948067,31.5146867 61.5423491,32.4390217 L74.4441595,35.1396739 C81.2831897,36.9222826 89.0055388,35.8616304 94.4303664,30.9995652 L97.655819,28.298913 L97.9502586,28.298913 L97.9413362,28.3211957 Z" fill="#000000"></path>
# </g>
# </g>
# </g>
# </g>
# </g>
# </g>
# </svg></icon>
# </div>
# </div>
# </a>
# <a class="top-header-btn top-header-btn--anchor header-search default" data-selector="cta-item-search" data-tealium-event="Internal Click" data-tealium-narrative="Search" href="/search-results.html" itemprop="url" itemscope="" itemtype="https://schema.org/SiteNavigationElement">
# <div class="icon-container">
# <div class="shape-container">
# <icon class="icon" data-selector="icon-Search" data-svg-path="/assets/utility-icons/Search.svg"><svg aria-hidden="true" focusable="false" height="24" width="24" xmlns="http://www.w3.org/2000/svg"><g fill="#D73E42" fill-rule="nonzero"><path d="M9.5 1v1a7.5 7.5 0 1 0 0 15 7.5 7.5 0 0 0 0-15V1zm0 0V0A9.5 9.5 0 0 1 19 9.5 9.5 9.5 0 0 1 9.5 19 9.5 9.5 0 0 1 0 9.5 9.5 9.5 0 0 1 9.5 0v1z"></path><path d="M14.793 16.207a1 1 0 0 1 1.414-1.414l7 7a1 1 0 0 1-1.414 1.414l-7-7z"></path></g></svg></icon>
# </div>
# </div>
# <span class="link-text" itemprop="name">Search</span>
# </a>
# <a class="business-nav-a" data-selector="cta-item-globallink" data-tealium-event="External Click" data-tealium-narrative="Personal" href="https://www.scottishwidows.co.uk" itemprop="url">
# <span class="btn-text" itemprop="name">Personal</span>
# </a>
# <a class="business-nav-a" data-selector="cta-item-globallink_1955940612" data-tealium-event="External Click" data-tealium-narrative="Employer" href="https://www.scottishwidows.co.uk/employer/" itemprop="url">
# <span class="btn-text" itemprop="name">Employer</span>
# </a>
# <a class="current business-nav-a" data-selector="cta-item-globallink_506150833" data-tealium-event="Internal Click" data-tealium-narrative="Adviser" href="/content/scottish-widows/extranet/en-gb.html" itemprop="url">
# <span class="btn-text" itemprop="name">Adviser</span>
# </a>
# <a data-selector="logo-anchor" data-tealium-event="Internal Click" href="/content/scottish-widows/extranet/en-gb.html" itemprop="url">
# <div class="icon-container">
# <div class="shape-container">
# <icon class="icon" data-selector="icon-sw_logo" data-svg-path="/assets/logo/sw_logo.svg" itemprop="logo"><svg aria-hidden="true" focusable="false" height="41px" version="1.1" viewbox="0 0 207 41" width="207px" xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink">
# <g fill="none" fill-rule="evenodd" stroke="none" stroke-width="1">
# <g transform="translate(-350.000000, -454.000000)">
# <g transform="translate(160.000000, 228.000000)">
# <g transform="translate(160.000000, 152.000000)">
# <g transform="translate(0.000000, 48.000000)">
# <g transform="translate(30.000000, 26.000000)">
# <path d="M193.103341,0.0757608696 C181.472974,6.76054348 169.088664,11.7072826 155.258922,11.1056522 C145.582565,10.6243478 136.642306,8.405 127.309461,6.78282609 C121.152996,5.70434783 114.99653,7.20173913 110.205194,11.4042391 L107.809526,13.5656522 L107.666767,13.5656522 C114.264892,6.12326087 123.057931,3.2398913 132.390776,4.1401087 L137.521164,4.79967391 L150.373901,7.02793478 C161.366315,8.81054348 173.973685,8.4673913 184.140776,4.08663043 C187.196935,2.91242588 190.176851,1.54905759 193.06319,0.00445652174 L193.103341,0.0757608696 Z" fill="#D3292E"></path>
# <path d="M97.9413362,28.3211957 C93.1053879,33.3615217 87.4842672,36.9044565 81.1805819,37.925 C71.8120474,39.3644565 62.8896336,36.3652174 53.8155388,35.046087 C43.8492026,33.303587 32.754181,32.7643478 23.0332112,35.5273913 C18.1983842,36.8035121 13.5153266,38.5964752 9.06517241,40.8752174 C8.91795259,40.8172826 8.96256466,40.8752174 8.96256466,40.7415217 L12.1880172,39.061413 C23.135819,33.5977174 34.6635776,29.8765217 47.6144612,30.656413 C52.2936213,30.9189714 56.948067,31.5146867 61.5423491,32.4390217 L74.4441595,35.1396739 C81.2831897,36.9222826 89.0055388,35.8616304 94.4303664,30.9995652 L97.655819,28.298913 L97.9502586,28.298913 L97.9413362,28.3211957 Z" fill="#000000"></path>
# </g>
# </g>
# </g>
# </g>
# </g>
# </g>
# </svg></icon>
# </div>
# </div>
# </a>
# <a class="top-header-btn top-header-btn--anchor top-header-btn--search search-click" data-selector="cta-item-search" data-tealium-event="Internal Click" data-tealium-narrative="Search" href="#" id="search-click" itemprop="url" itemscope="" itemtype="https://schema.org/SiteNavigationElement">
# <div class="icon-container">
# <div class="shape-container">
# <icon class="icon" data-selector="icon-Search" data-svg-path="/assets/utility-icons/Search.svg"><svg aria-hidden="true" focusable="false" height="24" width="24" xmlns="http://www.w3.org/2000/svg"><g fill="#D73E42" fill-rule="nonzero"><path d="M9.5 1v1a7.5 7.5 0 1 0 0 15 7.5 7.5 0 0 0 0-15V1zm0 0V0A9.5 9.5 0 0 1 19 9.5 9.5 9.5 0 0 1 9.5 19 9.5 9.5 0 0 1 0 9.5 9.5 9.5 0 0 1 9.5 0v1z"></path><path d="M14.793 16.207a1 1 0 0 1 1.414-1.414l7 7a1 1 0 0 1-1.414 1.414l-7-7z"></path></g></svg></icon>
# </div>
# </div>
# <span class="link-text" itemprop="name">Search</span>
# </a>
# <a class="top-header-btn top-header-btn--anchor" data-selector="cta-item-standard_copy" data-tealium-event="Internal Click" data-tealium-narrative="Help" href="/help.html" itemprop="url" itemscope="" itemtype="https://schema.org/SiteNavigationElement">
# <div class="icon-container">
# <div class="shape-container">
# <icon class="icon" data-selector="icon-Help" data-svg-path="/assets/utility-icons/Help.svg"><svg aria-hidden="true" focusable="false" height="24" width="24" xmlns="http://www.w3.org/2000/svg"><g fill="#D73E42" fill-rule="evenodd"><path d="M13.25 22.017c0 .985-.755 1.733-1.75 1.733-.96 0-1.75-.748-1.75-1.733 0-.985.79-1.767 1.75-1.767.995 0 1.75.782 1.75 1.767zM11.785 17.411h-.593c-.41 0-.842-.341-.842-.751v-2.356c0-2.799.741-3.742 2.175-4.834 1.23-.956 2.517-1.925 2.517-4.383 0-2.39-.607-2.914-2.997-2.914-1.297 0-2.536.375-3.628.955-.376.205-.923.051-1.128-.29l-.194-.448a.783.783 0 0 1 .307-1.059C8.632.581 10.304 0 12.045 0c3.141 0 5.494 1.468 5.494 5.087 0 3.209-1.704 4.335-3.24 5.53l-.171.137c-1.434 1.16-1.478 1.81-1.478 3.687v2.219c0 .41-.455.751-.865.751z"></path></g></svg></icon>
# </div>
# </div>
# <span class="link-text" itemprop="name">Help</span>
# </a>
# <a class="top-header-btn top-header-btn--anchor" data-selector="cta-item-standard_copy_716613795" data-tealium-event="Internal Click" data-tealium-narrative="Contact" href="/contact-us.html" itemprop="url" itemscope="" itemtype="https://schema.org/SiteNavigationElement">
# <div class="icon-container">
# <div class="shape-container">
# <icon class="icon" data-selector="icon-Contact" data-svg-path="/assets/utility-icons/Contact.svg"><svg aria-hidden="true" focusable="false" height="24" width="24" xmlns="http://www.w3.org/2000/svg"><path d="M16.586 21.987c.677.139 1.997-.868 2.346-1.71-.472-.836-2.523-3.137-3.404-3.878a6.405 6.405 0 0 0-.527.152c-.899.294-1.374.385-2.031.25-1.634-.332-5.192-6.057-4.908-7.77l.032-.2c.148-.913.272-1.332.661-1.775.123-.14.192-.224.232-.28-.278-1.213-1.273-3.926-1.781-4.764-.798.128-2.004 1.205-2.126 1.939-.936 5.664 6.316 16.978 11.506 18.036zM3.106 3.624C3.407 1.821 5.75-.164 7.615.012l.577.056.26.296.131.148c.757.864 2.08 4.452 2.394 6l.093.456-.103.272-.063.166c-.133.345-.288.56-.643.968-.048.054-.107.256-.192.779l-.033.203c-.115.692 2.797 5.376 3.335 5.485.199.041.442-.005 1.016-.193.622-.199.926-.272 1.314-.27l.47.003.26.19.124.091c1.07.785 3.805 3.845 4.283 4.959l.221.522-.096.34-.062.217c-.525 1.783-2.861 3.625-4.713 3.247C9.912 22.667 2 10.322 3.107 3.624z" fill="#D73E42" fill-rule="nonzero"></path></svg></icon>
# </div>
# </div>
# <span class="link-text" itemprop="name">Contact</span>
# </a>
# <a class="top-header-btn top-header-btn--anchor" data-selector="cta-item-standard_copy_716613" data-tealium-event="Internal Click" data-tealium-narrative="Register" href="/register.html" itemprop="url" itemscope="" itemtype="https://schema.org/SiteNavigationElement">
# <div class="icon-container">
# <div class="shape-container">
# <icon class="icon" data-selector="icon-Register" data-svg-path="/assets/utility-icons/Register.svg"><svg aria-hidden="true" focusable="false" height="24" width="24" xmlns="http://www.w3.org/2000/svg"><g fill="#D73E42" fill-rule="nonzero"><path d="m.348 21.37 1.289-3.865c.13-.496.389-.95.759-1.321l14.54-14.54a2.93 2.93 0 0 1 4.143 0l.75.749.747.748a2.93 2.93 0 0 1 0 4.144L8.037 21.827a2.86 2.86 0 0 1-1.26.739L2.8 23.888c-.818.225-1.56.121-2.073-.394-.516-.513-.62-1.258-.379-2.124zm5.855-.72a.93.93 0 0 0 .42-.24l14.54-14.54a.93.93 0 0 0-.001-1.315l-.747-.748-.75-.748a.93.93 0 0 0-1.315 0L3.811 17.596a1.015 1.015 0 0 0-.258.48L2.26 21.952c0 .003 1.313-.431 3.942-1.301zm-4.057 1.435a.4.4 0 0 0-.004-.004l.004.004zm-.01-.01.004.004a.4.4 0 0 0-.004-.005z"></path><path d="M3.258 18.469a1 1 0 1 1 1-1.732c.615.355 1.239.85 1.806 1.418.572.57 1.067 1.194 1.42 1.81a1 1 0 1 1-1.733.996c-.26-.45-.646-.937-1.101-1.392a6.97 6.97 0 0 0-1.392-1.1z"></path></g></svg></icon>
# </div>
# </div>
# <span class="link-text" itemprop="name">Register</span>
# </a>
# <a class="top-header-btn top-header-btn--anchor top-header-btn-highlight" data-selector="cta-item-standard" data-tealium-event="Internal Click" data-tealium-narrative="Log in" href="/log-in.html" itemprop="url" itemscope="" itemtype="https://schema.org/SiteNavigationElement">
# <div class="icon-container">
# <div class="shape-container">
# <icon class="icon" data-selector="icon-Padlock" data-svg-path="/assets/utility-icons/Padlock.svg"><svg aria-hidden="true" focusable="false" height="24" width="24" xmlns="http://www.w3.org/2000/svg"><g fill="#D73E42" fill-rule="evenodd"><path d="M11.499 13a2.493 2.493 0 0 0-.606 4.912c.172.066.363.088.543.088.36 0 .67-.088.67-.088A2.495 2.495 0 0 0 14 15.496 2.498 2.498 0 0 0 11.499 13m0 1.566c.514 0 .932.417.932.93 0 .425-.29.793-.734.905a1.275 1.275 0 0 1-.287.031h-.001l-.04-.016-.096-.024a.922.922 0 0 1-.704-.896c0-.513.417-.93.93-.93"></path><path d="M16 9a1 1 0 0 1-2 0V5.35C14 4.062 12.89 3 11.5 3 10.108 3 9 4.062 9 5.35V9a1 1 0 1 1-2 0V5.35C7 2.936 9.023 1 11.5 1 13.975 1 16 2.937 16 5.35V9zM10.5 17.5a1 1 0 0 1 2 0V19a1 1 0 0 1-2 0v-1.5z" fill-rule="nonzero"></path><path d="M17.41 9v1H5.59c-.34 0-.59.235-.59.488v11.024c0 .253.25.488.59.488h11.82c.347 0 .59-.229.59-.488V10.488c0-.253-.25-.488-.59-.488V9zm0 0V8C18.824 8 20 9.1 20 10.488v11.024C20 22.904 18.835 24 17.41 24H5.59C4.176 24 3 22.9 3 21.512V10.488C3 9.1 4.175 8 5.59 8h11.82v1z" fill-rule="nonzero"></path></g></svg></icon>
# </div>
# </div>
# <span class="link-text" itemprop="name">Log in</span>
# </a>
# <a data-tealium-event="Internal Click" href="/content/scottish-widows/extranet/en-gb.html">
# <div class="icon-container">
# <div class="shape-container">
# <icon data-selector="icon-home" data-svg-path="/etc/designs/scottish-widows/clientlibs/icons/home.svg"><svg aria-hidden="true" focusable="false" style="enable-background:new 0 0 18 17" version="1.1" viewbox="0 0 18 17" x="0" xml:space="preserve" xmlns="http://www.w3.org/2000/svg" y="0"><style>.st0{fill:none;stroke-width:2}</style><g><g transform="translate(-160 -15)"><g transform="translate(160 13)"><g transform="translate(0 2)"><g transform="translate(0 1)"><path class="st0" d="M.7 8.3 9 .8l8.4 7.5"></path></g><path class="st0" d="M4 6.3v7c0 1.1.9 2 2 2h6c1.1 0 2-.9 2-2v-7"></path></g></g></g></g></svg></icon>
# </div>
# </div>
# </a>
# <a data-tealium-event="Internal Click" data-tealium-narrative="Products" href="/products.html" itemprop="url" tabindex="0">
# <span class="btn-text" itemprop="name">Products</span>
# </a>
# <a data-tealium-event="Internal Click" data-tealium-narrative="Individual Pensions" href="/products/individual-pensions.html" itemprop="url" tabindex="0">
# <span class="btn-text" itemprop="name">Individual Pensions</span>
# </a>
# <a data-selector="cta-item-0" data-tealium-action="Link Click" data-tealium-event="Internal Click" data-tealium-listener="null" data-tealium-narrative="Retirement Account" data-tealium-tracking="null" data-tealium-value="null" href="/products/individual-pensions/why-retirement-account.html" itemprop="url">
# <span class="btn-text" itemprop="name">Retirement Account</span>
# </a>
# <a data-selector="cta-item-1" data-tealium-action="Link Click" data-tealium-event="Internal Click" data-tealium-listener="null" data-tealium-narrative="Stakeholder Pension" data-tealium-tracking="null" data-tealium-value="null" href="/products/individual-pensions/stakeholder-pension.html" itemprop="url">
# <span class="btn-text" itemprop="name">Stakeholder Pension</span>
# </a>
# <a data-selector="cta-item-2" data-tealium-action="Link Click" data-tealium-event="Internal Click" data-tealium-listener="null" data-tealium-narrative="Pension Top-Up Plan" data-tealium-tracking="null" data-tealium-value="null" href="/products/individual-pensions/personal-pension-top-up.html" itemprop="url">
# <span class="btn-text" itemprop="name">Pension Top-Up Plan</span>
# </a>
# <a data-selector="cta-item-0" data-tealium-action="Link Click" data-tealium-event="Internal Click" data-tealium-listener="null" data-tealium-narrative="How we can help online" data-tealium-tracking="null" data-tealium-value="null" href="/online-services/how-we-can-help-online.html" itemprop="url">
# <span class="btn-text" itemprop="name">How we can help online</span>
# </a>
# <a data-selector="cta-item-1" data-tealium-action="Link Click" data-tealium-event="Internal Click" data-tealium-listener="null" data-tealium-narrative="About our funds" data-tealium-tracking="null" data-tealium-value="null" href="/funds/funds-information.html" itemprop="url">
# <span class="btn-text" itemprop="name">About our funds</span>
# </a>
# <a data-selector="cta-item-2" data-tealium-action="Link Click" data-tealium-event="Internal Click" data-tealium-listener="null" data-tealium-narrative="Pension tools" data-tealium-tracking="null" data-tealium-value="null" href="/tools/pensions-and-investments.html" itemprop="url">
# <span class="btn-text" itemprop="name">Pension tools</span>
# </a>
# <a data-tealium-event="External Click" data-tealium-narrative="Scottish Widows Platform" href="https://platform.scottishwidows.co.uk/" itemprop="url" tabindex="0">
# <span class="btn-text" itemprop="name">Scottish Widows Platform</span>
# </a>
# <a data-selector="cta-item-0" data-tealium-action="Link Click" data-tealium-event="External Click" data-tealium-listener="null" data-tealium-narrative="Our market leading technology" data-tealium-tracking="null" data-tealium-value="null" href="https://platform.scottishwidows.co.uk/" itemprop="url">
# <span class="btn-text" itemprop="name">Our market leading technology</span>
# </a>
# <a data-selector="cta-item-1" data-tealium-action="Link Click" data-tealium-event="External Click" data-tealium-listener="null" data-tealium-narrative="Products and services" data-tealium-tracking="null" data-tealium-value="null" href="https://platform.scottishwidows.co.uk/products-and-services/" itemprop="url">
# <span class="btn-text" itemprop="name">Products and services</span>
# </a>
# <a data-selector="cta-item-2" data-tealium-action="Link Click" data-tealium-event="External Click" data-tealium-listener="null" data-tealium-narrative="Login" data-tealium-tracking="null" data-tealium-value="null" href="https://www.scottishwidows-platform.com/login" itemprop="url">
# <span class="btn-text" itemprop="name">Login</span>
# </a>
# <a data-selector="cta-item-0" data-tealium-action="Link Click" data-tealium-event="External Click" data-tealium-listener="null" data-tealium-narrative="Literature library" data-tealium-tracking="null" data-tealium-value="null" href="https://platform.scottishwidows.co.uk/literature-library" itemprop="url">
# <span class="btn-text" itemprop="name">Literature library</span>
# </a>
# <a data-selector="cta-item-1" data-tealium-action="Link Click" data-tealium-event="External Click" data-tealium-listener="null" data-tealium-narrative="Investment Options" data-tealium-tracking="null" data-tealium-value="null" href="https://platform.scottishwidows.co.uk/products-and-services/investment-options/" itemprop="url">
# <span class="btn-text" itemprop="name">Investment Options</span>
# </a>
# <a data-selector="cta-item-2" data-tealium-action="Link Click" data-tealium-event="External Click" data-tealium-listener="null" data-tealium-narrative="Tools" data-tealium-tracking="null" data-tealium-value="null" href="https://platform.scottishwidows.co.uk/adviser-gateway/tools-technical/" itemprop="url">
# <span class="btn-text" itemprop="name">Tools</span>
# </a>
# <a data-tealium-event="Internal Click" data-tealium-narrative="Workplace Savings" href="/products/workplace-saving.html" itemprop="url" tabindex="0">
# <span class="btn-text" itemprop="name">Workplace Savings</span>
# </a>
# <a data-selector="cta-item-0" data-tealium-action="Link Click" data-tealium-event="Internal Click" data-tealium-listener="null" data-tealium-narrative="About Workplace" data-tealium-tracking="null" data-tealium-value="null" href="/products/workplace-saving.html" itemprop="url">
# <span class="btn-text" itemprop="name">About Workplace</span>
# </a>
# <a data-selector="cta-item-1" data-tealium-action="Link Click" data-tealium-event="Internal Click" data-tealium-listener="null" data-tealium-narrative="Investment proposition" data-tealium-tracking="null" data-tealium-value="null" href="/products/workplace-saving/investment-choices.html" itemprop="url">
# <span class="btn-text" itemprop="name">Investment proposition</span>
# </a>
# <a data-selector="cta-item-2" data-tealium-action="Link Click" data-tealium-event="Internal Click" data-tealium-listener="null" data-tealium-narrative="Employee engagement" data-tealium-tracking="null" data-tealium-value="null" href="/products/workplace-saving/employee-engagement.html" itemprop="url">
# <span class="btn-text" itemprop="name">Employee engagement</span>
# </a>
# <a data-selector="cta-item-3" data-tealium-action="Link Click" data-tealium-event="Internal Click" data-tealium-listener="null" data-tealium-narrative="Support" data-tealium-tracking="null" data-tealium-value="null" href="/products/workplace-saving/support.html" itemprop="url">
# <span class="btn-text" itemprop="name">Support</span>
# </a>
# <a data-selector="cta-item-4" data-tealium-action="Link Click" data-tealium-event="Internal Click" data-tealium-listener="null" data-tealium-narrative="New business" data-tealium-tracking="null" data-tealium-value="null" href="/products/workplace-saving/apply.html" itemprop="url">
# <span class="btn-text" itemprop="name">New business</span>
# </a>
# <a data-selector="cta-item-5" data-tealium-action="Link Click" data-tealium-event="External Click" data-tealium-listener="null" data-tealium-narrative="Price a workplace scheme" data-tealium-tracking="null" data-tealium-value="null" href="https://emails.scottishwidows.co.uk/workplace-adviser-quotes" itemprop="url">
# <span class="btn-text" itemprop="name">Price a workplace scheme</span>
# </a>
# <a data-selector="cta-item-0" data-tealium-action="Link Click" data-tealium-event="Internal Click" data-tealium-listener="null" data-tealium-narrative="How we can help online" data-tealium-tracking="null" data-tealium-value="null" href="/online-services/how-we-can-help-online.html" itemprop="url">
# <span class="btn-text" itemprop="name">How we can help online</span>
# </a>
# <a data-selector="cta-item-1" data-tealium-action="Link Click" data-tealium-event="Internal Click" data-tealium-listener="null" data-tealium-narrative="About our funds" data-tealium-tracking="null" data-tealium-value="null" href="/funds/funds-information.html" itemprop="url">
# <span class="btn-text" itemprop="name">About our funds</span>
# </a>
# <a data-selector="cta-item-2" data-tealium-action="Link Click" data-tealium-event="Internal Click" data-tealium-listener="null" data-tealium-narrative="Pension tools" data-tealium-tracking="null" data-tealium-value="null" href="/tools/pensions-and-investments.html" itemprop="url">
# <span class="btn-text" itemprop="name">Pension tools</span>
# </a>
# <a data-tealium-event="Internal Click" data-tealium-narrative="Protection" href="/products/protection.html" itemprop="url" tabindex="0">
# <span class="btn-text" itemprop="name">Protection</span>
# </a>
# <a data-selector="cta-item-0" data-tealium-action="Link Click" data-tealium-event="Internal Click" data-tealium-listener="null" data-tealium-narrative="Life Cover" data-tealium-tracking="null" data-tealium-value="null" href="/products/protection/personal-protection-life-cover.html" itemprop="url">
# <span class="btn-text" itemprop="name">Life Cover</span>
# </a>
# <a data-selector="cta-item-1" data-tealium-action="Link Click" data-tealium-event="Internal Click" data-tealium-listener="null" data-tealium-narrative="Life with Critical Illness Cover" data-tealium-tracking="null" data-tealium-value="null" href="/products/protection/personal-protection-life-cover-with-critical-illness-cover.html" itemprop="url">
# <span class="btn-text" itemprop="name">Life with Critical Illness Cover</span>
# </a>
# <a data-selector="cta-item-2" data-tealium-action="Link Click" data-tealium-event="Internal Click" data-tealium-listener="null" data-tealium-narrative="Critical Illness Cover" data-tealium-tracking="null" data-tealium-value="null" href="/products/protection/personal-protection-critical-illness-cover.html" itemprop="url">
# <span class="btn-text" itemprop="name">Critical Illness Cover</span>
# </a>
# <a data-selector="cta-item-0" data-tealium-action="Link Click" data-tealium-event="Internal Click" data-tealium-listener="null" data-tealium-narrative="Life Cover" data-tealium-tracking="null" data-tealium-value="null" href="/products/protection/business-protection-life-cover.html" itemprop="url">
# <span class="btn-text" itemprop="name">Life Cover</span>
# </a>
# ...
# <icon class="icon" data-selector="icon-linkedin_grey" data-svg-path="/assets/social/linkedin_grey.svg"><svg aria-hidden="true" focusable="false" height="21" width="21" xmlns="http://www.w3.org/2000/svg"><path d="M18.594 1C19.369 1 20 1.614 20 2.37v16.259c0 .757-.631 1.371-1.406 1.371H2.403C1.629 20 1 19.386 1 18.629V2.369C1 1.615 1.629 1 2.403 1zM17.19 17.19v-4.973c0-2.441-.527-4.32-3.38-4.32-1.371 0-2.29.752-2.666 1.465h-.038V8.123H8.403v9.067h2.816v-4.485c0-1.183.225-2.328 1.69-2.328 1.446 0 1.465 1.352 1.465 2.404v4.41zM5.227 6.884a1.635 1.635 0 0 0 0-3.268 1.634 1.634 0 1 0 0 3.268zM3.817 17.19h2.818V8.123H3.817z" fill="#848484"></path></svg></icon>
# </div>
# </div>
# <span class="sr-only">share on Linkedin</span>
# </a>
# <a class="social-share" data-selector="cta-item-twitter" data-tealium-event="External Click" href="https://twitter.com/share" id="twitter">
# <div class="icon-container">
# <div class="shape-container">
# <icon class="icon" data-selector="icon-twitter_grey" data-svg-path="/assets/social/twitter_grey.svg"><svg aria-hidden="true" focusable="false" height="21" width="21" xmlns="http://www.w3.org/2000/svg"><path d="M21 4.01a8.647 8.647 0 0 1-2.475.674 4.302 4.302 0 0 0 1.895-2.37 8.654 8.654 0 0 1-2.736 1.04A4.313 4.313 0 0 0 14.539 2c-2.38 0-4.308 1.919-4.308 4.285 0 .336.038.663.111.977a12.253 12.253 0 0 1-8.88-4.478 4.278 4.278 0 0 0 1.333 5.721A4.308 4.308 0 0 1 .844 7.97v.054A4.294 4.294 0 0 0 4.3 12.226a4.339 4.339 0 0 1-1.946.073 4.31 4.31 0 0 0 4.025 2.976 8.674 8.674 0 0 1-5.351 1.835c-.348 0-.69-.02-1.028-.06a12.243 12.243 0 0 0 6.604 1.925c7.925 0 12.259-6.53 12.259-12.193 0-.186-.005-.37-.013-.554A8.73 8.73 0 0 0 21 4.009" fill="#848484" fill-rule="evenodd"></path></svg></icon>
# </div>
# </div>
# <span class="sr-only">Share on Twitter</span>
# </a>
# <a class="social-share" data-selector="cta-item-fb" data-tealium-event="External Click" href="https://www.facebook.com/sharer/sharer.php" id="fb">
# <div class="icon-container">
# <div class="shape-container">
# <icon class="icon" data-selector="icon-facebook_grey" data-svg-path="/assets/social/facebook_grey.svg"><svg aria-hidden="true" focusable="false" height="21" width="21" xmlns="http://www.w3.org/2000/svg"><path d="M18.951 1H2.05C1.469 1 1 1.47 1 2.049V18.95C1 19.531 1.47 20 2.049 20h9.1v-7.358H8.673V9.775h2.476V7.66c0-2.454 1.498-3.79 3.688-3.79a20.3 20.3 0 0 1 2.212.113v2.564l-1.518.001c-1.19 0-1.421.566-1.421 1.396v1.83h2.84l-.37 2.868h-2.47V20h4.841c.58 0 1.049-.47 1.049-1.049V2.05C20 1.469 19.53 1 18.951 1" fill="#848484" fill-rule="evenodd"></path></svg></icon>
# </div>
# </div>
# <span class="sr-only">Share on Facebook</span>
# </a>
# <a aria-label="Send an email now" data-selector="cta-item-email" href="mailto:?subject= https://adviser.scottishwidows.co.uk/literature-library.html&amp;body= Literature https://adviser.scottishwidows.co.uk/literature-library.html">
# <div class="icon-container">
# <div class="shape-container">
# <icon class="icon" data-selector="icon-email_grey" data-svg-path="/assets/social/email_grey.svg"><svg aria-hidden="true" focusable="false" height="21" width="21" xmlns="http://www.w3.org/2000/svg"><g fill="none" fill-rule="evenodd" stroke="#848484" stroke-width="2"><rect height="13" rx="2" width="19" x="1" y="4"></rect><path d="m2 5 8.5 6L19 5" stroke-linecap="round" stroke-linejoin="round"></path></g></svg></icon>
# </div>
# </div>
# </a>
# <a data-selector="cta-item-0" data-tealium-action="Link Click" data-tealium-event="Internal Click" data-tealium-listener="null" data-tealium-narrative="Agency set-up" data-tealium-tracking="null" data-tealium-value="null" href="/help/agency-set-up.html" itemprop="url">
# <span class="btn-text" itemprop="name">Agency set-up</span>
# <span class="sr-only">More information on how to set up an agency</span>
# </a>
# <a data-selector="cta-item-1" data-tealium-action="Link Click" data-tealium-event="Internal Click" data-tealium-listener="null" data-tealium-narrative="Online services" data-tealium-tracking="null" data-tealium-value="null" href="/online-services.html" itemprop="url">
# <span class="btn-text" itemprop="name">Online services</span>
# </a>
# <a data-selector="cta-item-2" data-tealium-action="Link Click" data-tealium-event="Internal Click" data-tealium-listener="null" data-tealium-narrative="Contact us" data-tealium-tracking="null" data-tealium-value="null" href="/contact-us.html" itemprop="url">
# <span class="btn-text" itemprop="name">Contact us</span>
# </a>
# <a data-selector="cta-item-0" data-tealium-action="Link Click" data-tealium-event="Internal Click" data-tealium-listener="null" data-tealium-narrative="Individual Pensions" data-tealium-tracking="null" data-tealium-value="null" href="/products/individual-pensions.html" itemprop="url">
# <span class="btn-text" itemprop="name">Individual Pensions</span>
# </a>
# <a data-selector="cta-item-1" data-tealium-action="Link Click" data-tealium-event="External Click" data-tealium-listener="null" data-tealium-narrative="Scottish Widows Platform" data-tealium-tracking="null" data-tealium-value="null" href="https://platform.scottishwidows.co.uk/" itemprop="url">
# <span class="btn-text" itemprop="name">Scottish Widows Platform</span>
# </a>
# <a data-selector="cta-item-2" data-tealium-action="Link Click" data-tealium-event="Internal Click" data-tealium-listener="null" data-tealium-narrative="Workplace Savings" data-tealium-tracking="null" data-tealium-value="null" href="/products/workplace-saving.html" itemprop="url">
# <span class="btn-text" itemprop="name">Workplace Savings</span>
# </a>
# <a data-selector="cta-item-3" data-tealium-action="Link Click" data-tealium-event="Internal Click" data-tealium-listener="null" data-tealium-narrative="Annuities" data-tealium-tracking="null" data-tealium-value="null" href="/products/annuities.html" itemprop="url">
# <span class="btn-text" itemprop="name">Annuities</span>
# </a>
# <a data-selector="cta-item-4" data-tealium-action="Link Click" data-tealium-event="Internal Click" data-tealium-listener="null" data-tealium-narrative="Protection" data-tealium-tracking="null" data-tealium-value="null" href="/products/protection.html" itemprop="url">
# <span class="btn-text" itemprop="name">Protection</span>
# </a>
# <a data-selector="cta-item-5" data-tealium-action="Link Click" data-tealium-event="Internal Click" data-tealium-listener="null" data-tealium-narrative="Trusts" data-tealium-tracking="null" data-tealium-value="null" href="/products/trusts.html" itemprop="url">
# <span class="btn-text" itemprop="name">Trusts</span>
# </a>
# <a data-selector="cta-item-6" data-tealium-action="Link Click" data-tealium-event="Internal Click" data-tealium-listener="null" data-tealium-narrative="Savings" data-tealium-tracking="null" data-tealium-value="null" href="/products/savings.html" itemprop="url">
# <span class="btn-text" itemprop="name">Savings</span>
# </a>
# <a data-selector="cta-item-7" data-tealium-action="Link Click" data-tealium-event="Internal Click" data-tealium-listener="null" data-tealium-narrative="Mortgages" data-tealium-tracking="null" data-tealium-value="null" href="/products/mortgages.html" itemprop="url">
# <span class="btn-text" itemprop="name">Mortgages</span>
# </a>
# <a data-selector="cta-item-0" data-tealium-action="Link Click" data-tealium-event="External Click" data-tealium-listener="null" data-tealium-narrative="Factsheets, price &amp; performance" data-tealium-tracking="null" data-tealium-value="null" href="https://digital.feprecisionplus.com/SWFunds?defaultcategorycode=sw" itemprop="url" target="_blank">
# <span class="btn-text" itemprop="name">Factsheets, price &amp; performance</span>
# <span class="sr-only">Takes you to our funds tool opens in a new tab</span>
# </a>
# <a data-selector="cta-item-1" data-tealium-action="Link Click" data-tealium-event="Internal Click" data-tealium-listener="null" data-tealium-narrative="Fund governance" data-tealium-tracking="null" data-tealium-value="null" href="/funds/fund-governance.html" itemprop="url">
# <span class="btn-text" itemprop="name">Fund governance</span>
# </a>
# <a data-selector="cta-item-2" data-tealium-action="Link Click" data-tealium-event="Internal Click" data-tealium-listener="null" data-tealium-narrative="Fund information" data-tealium-tracking="null" data-tealium-value="null" href="/funds/funds-information.html" itemprop="url">
# <span class="btn-text" itemprop="name">Fund information</span>
# </a>
# <a data-selector="cta-item-0" data-tealium-action="Link Click" data-tealium-event="Internal Click" data-tealium-listener="null" data-tealium-narrative="About Scottish Widows" data-tealium-tracking="null" data-tealium-value="null" href="/about.html" itemprop="url">
# <span class="btn-text" itemprop="name">About Scottish Widows</span>
# </a>
# <a data-selector="cta-item-1" data-tealium-action="Link Click" data-tealium-event="Internal Click" data-tealium-listener="null" data-tealium-narrative="Financial Strength" data-tealium-tracking="null" data-tealium-value="null" href="/about/financial-information.html" itemprop="url">
# <span class="btn-text" itemprop="name">Financial Strength</span>
# </a>
# <a data-selector="cta-item-2" data-tealium-action="Link Click" data-tealium-event="Internal Click" data-tealium-listener="null" data-tealium-narrative="Our awards" data-tealium-tracking="null" data-tealium-value="null" href="/about/award.html" itemprop="url">
# <span class="btn-text" itemprop="name">Our awards</span>
# <span class="sr-only">Our awards</span>
# </a>
# <a data-selector="cta-item-3" data-tealium-action="Link Click" data-tealium-event="Internal Click" data-tealium-listener="null" data-tealium-narrative="Scottish Widows Bank" data-tealium-tracking="null" data-tealium-value="null" href="/scottish-widows-bank.html" itemprop="url">
# <span class="btn-text" itemprop="name">Scottish Widows Bank</span>
# </a>
# <a data-selector="cta-item-4" data-tealium-action="Link Click" data-tealium-event="External Click" data-tealium-listener="null" data-tealium-narrative="Lloyds Banking Group" data-tealium-tracking="null" data-tealium-value="null" href="https://www.scottishwidows.co.uk/about_us/who_we_are/lloyds_banking_group_sites.html" itemprop="url">
# <span class="btn-text" itemprop="name">Lloyds Banking Group</span>
# </a>
# <a data-selector="cta-item-5" data-tealium-action="Link Click" data-tealium-event="External Click" data-tealium-listener="null" data-tealium-narrative="Careers" data-tealium-tracking="null" data-tealium-value="null" href="https://www.scottishwidows.co.uk/about_us/work_with_us/" itemprop="url">
# <span class="btn-text" itemprop="name">Careers</span>
# </a>
# <a data-selector="Cookies" data-tealium-action="Link Click" data-tealium-event="Internal Click" data-tealium-listener="null" data-tealium-narrative="Cookies" data-tealium-tracking="null" data-tealium-value="null" href="/legal-and-privacy.html#cookies">
# <span class="btn-text">Cookies</span>
# </a>
# <a data-selector="Legal Information" data-tealium-action="Link Click" data-tealium-event="Internal Click" data-tealium-listener="null" data-tealium-narrative="Legal Information" data-tealium-tracking="null" data-tealium-value="null" href="/legal-and-privacy.html">
# <span class="btn-text">Legal Information</span>
# </a>
# <a data-selector="Accessibility" data-tealium-action="Link Click" data-tealium-event="External Click" data-tealium-listener="null" data-tealium-narrative="Accessibility" data-tealium-tracking="null" data-tealium-value="null" href="https://www.scottishwidows.co.uk/about_us/serving_our_customers/accessibility.html">
# <span class="btn-text">Accessibility</span>
# </a>
# <a data-selector="Site map" data-tealium-action="Link Click" data-tealium-event="Internal Click" data-tealium-listener="null" data-tealium-narrative="Site map" data-tealium-tracking="null" data-tealium-value="null" href="/sitemap.html">
# <span class="btn-text">Site map</span>
# </a>
# <a data-selector="Modern Slavery Statement (PDF, 2MB)" data-tealium-action="Link Click" data-tealium-event="Internal Click" data-tealium-listener="null" data-tealium-narrative="Modern Slavery Statement (PDF, 2MB)" data-tealium-tracking="null" data-tealium-value="null" href="/assets/literature/docs/2022-lbg-modern-slavery-statement.pdf" target="_blank">
# <span class="btn-text">Modern Slavery Statement (PDF, 2MB)</span>
# <span class="sr-only">Opens in a new tab</span>
# </a>
# <a data-selector="cta-item-0" data-tealium-action="Link Click" data-tealium-event="External Click" data-tealium-listener="null" data-tealium-tracking="null" data-tealium-value="null" href="https://www.linkedin.com/showcase/scottish-widows-adviser/">
# <div class="icon-container">
# <div class="shape-container">
# <icon class="icon" data-selector="icon-linkedin" data-svg-path="/assets/social/linkedin.svg"><svg aria-hidden="true" focusable="false" viewbox="0 0 24 24" xmlns="http://www.w3.org/2000/svg"><path d="M22.2 0c1 0 1.8.8 1.8 1.7v20.6c0 .9-.8 1.7-1.8 1.7H1.8c-1 0-1.8-.8-1.8-1.7V1.7C0 .8.8 0 1.8 0h20.4zM3.6 20.5h3.5V9H3.6v11.5zm16.9 0v-6.3c0-3.1-.7-5.5-4.3-5.5-1.8 0-2.9 1-3.4 1.9V9H9.4v11.5h3.5v-5.7c0-1.5.3-3 2.1-3 1.9 0 1.9 1.8 1.9 3.1v5.6h3.6zM5.3 7.4c1.2 0 2.1-.9 2.1-2 0-1.2-.9-2.1-2.1-2.1-1.1 0-2 .9-2 2.1 0 1.1.9 2 2 2z"></path></svg></icon>
# </div>
# </div>
# <span class="sr-only">Visit the Scottish Widows Linkedin page.</span>
# </a>
# <a data-selector="cta-item-1" data-tealium-action="Link Click" data-tealium-event="External Click" data-tealium-listener="null" data-tealium-tracking="null" data-tealium-value="null" href="https://twitter.com/SWidowsAdviser">
# <div class="icon-container">
# <div class="shape-container">
# <icon class="icon" data-selector="icon-twitter" data-svg-path="/assets/social/twitter.svg"><svg aria-hidden="true" focusable="false" viewbox="0 0 24 20" xmlns="http://www.w3.org/2000/svg"><path d="M24 2.3c-.9.4-1.8.7-2.8.8 1-.6 1.8-1.6 2.1-2.7-.9.5-2 .9-3.1 1.2C19.3.6 18 0 16.6 0c-2.7 0-4.9 2.2-4.9 4.9 0 .4 0 .8.1 1.2C7.7 5.9 4.1 3.9 1.7.9c-.5.7-.7 1.6-.7 2.5 0 1.7.9 3.2 2.2 4.1-.8 0-1.6-.2-2.2-.6V7c0 2.4 1.7 4.4 3.9 4.8-.4.1-.8.2-1.3.2-.3 0-.6 0-.9-.1.6 2 2.4 3.4 4.6 3.4-1.7 1.4-3.8 2.2-6.1 2.2-.4 0-.8-.1-1.2-.1 2.2 1.4 4.8 2.2 7.5 2.2 9.1 0 14.1-7.5 14.1-14.1 0-.2 0-.4-.1-.6 1-.7 1.8-1.6 2.5-2.6"></path></svg></icon>
# </div>
# </div>
# <span class="sr-only">Share on Twitter</span>
# </a>
# <a data-selector="cta-item-2" data-tealium-action="Link Click" data-tealium-event="External Click" data-tealium-listener="null" data-tealium-tracking="null" data-tealium-value="null" href="https://www.facebook.com/scottishwidows">
# <div class="icon-container">
# <div class="shape-container">
# <icon class="icon" data-selector="icon-facebook" data-svg-path="/assets/social/facebook.svg"><svg aria-hidden="true" focusable="false" viewbox="0 0 24 24" xmlns="http://www.w3.org/2000/svg"><path d="M22.7 0H1.3C.6 0 0 .6 0 1.3v21.4c0 .7.6 1.3 1.3 1.3h11.5v-9.3H9.7v-3.6h3.1V8.4c0-3.1 1.9-4.8 4.7-4.8 1.3 0 2.4.1 2.8.2V7h-1.9c-1.5 0-1.8.7-1.8 1.8v2.3h3.5l-.4 3.6h-3.1V24h6.1c.7 0 1.3-.6 1.3-1.3V1.3c0-.7-.6-1.3-1.3-1.3"></path></svg></icon>
# </div>
# </div>
# <span class="sr-only">Share on Facebook</span>
# </a>
# <a data-selector="cta-item-3" data-tealium-action="Link Click" data-tealium-event="External Click" data-tealium-listener="null" data-tealium-tracking="null" data-tealium-value="null" href="https://www.youtube.com/user/scottishwidows" target="_blank">
# <div class="icon-container">
# <div class="shape-container">
# <icon class="icon" data-selector="icon-youtube_white" data-svg-path="/assets/social/youtube_white.svg"><svg aria-hidden="true" focusable="false" height="21" width="21" xmlns="http://www.w3.org/2000/svg"><path d="M17.923 3.918c.818.23 1.461.908 1.68 1.768C20 7.246 20 10.5 20 10.5s0 3.254-.397 4.814c-.219.86-.862 1.538-1.68 1.768-1.482.418-7.423.418-7.423.418s-5.941 0-7.423-.418c-.818-.23-1.462-.908-1.68-1.768C1 13.754 1 10.5 1 10.5s0-3.254.397-4.814c.218-.86.862-1.538 1.68-1.768C4.559 3.5 10.5 3.5 10.5 3.5s5.941 0 7.423.418zM8 13.455l6-2.955-6-2.955z" fill="#fff" fill-rule="evenodd"></path></svg></icon>
# </div>
# </div>
# <span class="sr-only">Opens the Scottish Widows Youtube page: link opens in new tab</span>
# </a>

# %%
# all the resulting pdf files are in the anchor elements with "title" class
download_links = soup.find_all(class_="title")

print(f"Total downlaodable links: {len(download_links)}")

download_links[0]
# Out:
# Total downlaodable links: 223
# <a class="title" download="" href="/assets/literature/docs/42365.pdf" target="_blank">
# 					Which trust form should I use?
# 				</a>

# %%
print(download_links[0].get("href"))
print(download_links[0].string.strip())
# Out:
# /assets/literature/docs/42365.pdf
# Which trust form should I use?

# %%
pdf_uris = [download_link.get("href") for download_link in download_links]
_ = [print("https://adviser.scottishwidows.co.uk/" + uri) for uri in pdf_uris]
# Out:
# https://adviser.scottishwidows.co.uk//assets/literature/docs/42365.pdf
# https://adviser.scottishwidows.co.uk//assets/literature/docs/53075.pdf
# https://adviser.scottishwidows.co.uk//assets/literature/docs/41848sp.pdf
# https://adviser.scottishwidows.co.uk//assets/literature/docs/56737.pdf
# https://adviser.scottishwidows.co.uk//assets/literature/docs/E2103.pdf
# https://adviser.scottishwidows.co.uk//assets/literature/docs/fsaSWplcFSAReturn2007.pdf
# https://adviser.scottishwidows.co.uk//assets/literature/docs/27316.pdf
# https://adviser.scottishwidows.co.uk//assets/literature/docs/28742a.pdf
# https://adviser.scottishwidows.co.uk//assets/literature/docs/56241.pdf
# https://adviser.scottishwidows.co.uk//assets/literature/docs/26489.pdf
# https://adviser.scottishwidows.co.uk//assets/literature/docs/54575.pdf
# https://adviser.scottishwidows.co.uk//assets/literature/docs/24696.pdf
# https://adviser.scottishwidows.co.uk//assets/literature/docs/51084.pdf
# https://adviser.scottishwidows.co.uk//assets/literature/docs/55188.pdf
# https://adviser.scottishwidows.co.uk//assets/literature/docs/55915.pdf
# https://adviser.scottishwidows.co.uk//assets/literature/docs/secure_email_user_guide.pdf
# https://adviser.scottishwidows.co.uk//assets/literature/docs/28646.pdf
# https://adviser.scottishwidows.co.uk//assets/literature/docs/28645.pdf
# https://adviser.scottishwidows.co.uk//assets/literature/docs/49728.pdf
# https://adviser.scottishwidows.co.uk//assets/literature/docs/51175.pdf
# https://adviser.scottishwidows.co.uk//assets/literature/docs/60002.pdf
# https://adviser.scottishwidows.co.uk//assets/literature/docs/60076.pdf
# https://adviser.scottishwidows.co.uk//assets/literature/docs/14199.pdf
# https://adviser.scottishwidows.co.uk//assets/literature/docs/46458JG.pdf
# https://adviser.scottishwidows.co.uk//assets/literature/docs/55013.pdf
# https://adviser.scottishwidows.co.uk//assets/literature/docs/32557.pdf
# https://adviser.scottishwidows.co.uk//assets/literature/docs/28484.pdf
# https://adviser.scottishwidows.co.uk//assets/literature/docs/53402.pdf
# https://adviser.scottishwidows.co.uk//assets/literature/docs/26627.pdf
# https://adviser.scottishwidows.co.uk//assets/literature/docs/55233.pdf
# https://adviser.scottishwidows.co.uk//assets/literature/docs/55217.pdf
# https://adviser.scottishwidows.co.uk//assets/literature/docs/56047.pdf
# https://adviser.scottishwidows.co.uk//assets/literature/docs/53062.pdf
# https://adviser.scottishwidows.co.uk//assets/literature/docs/53061.pdf
# https://adviser.scottishwidows.co.uk//assets/literature/docs/35772.pdf
# https://adviser.scottishwidows.co.uk//assets/literature/docs/SW57764.pdf
# https://adviser.scottishwidows.co.uk//assets/literature/docs/51234.pdf
# https://adviser.scottishwidows.co.uk//assets/literature/docs/54879.pdf
# https://adviser.scottishwidows.co.uk//assets/literature/docs/60130.pdf
# https://adviser.scottishwidows.co.uk//assets/literature/docs/52870.pdf
# https://adviser.scottishwidows.co.uk//assets/literature/docs/1_339160-0.pdf
# https://adviser.scottishwidows.co.uk//assets/literature/docs/53633.pdf
# https://adviser.scottishwidows.co.uk//assets/literature/docs/SW55063.pdf
# https://adviser.scottishwidows.co.uk//assets/literature/docs/44619.pdf
# https://adviser.scottishwidows.co.uk//assets/literature/docs/150716DA.pdf
# https://adviser.scottishwidows.co.uk//assets/literature/docs/55863.pdf
# https://adviser.scottishwidows.co.uk//assets/literature/docs/56701.pdf
# https://adviser.scottishwidows.co.uk//assets/literature/docs/56160.pdf
# https://adviser.scottishwidows.co.uk//assets/literature/docs/55012.pdf
# https://adviser.scottishwidows.co.uk//assets/literature/docs/44621.pdf
# https://adviser.scottishwidows.co.uk//assets/literature/docs/60318.pdf
# https://adviser.scottishwidows.co.uk//assets/literature/docs/47937.pdf
# https://adviser.scottishwidows.co.uk//assets/literature/docs/52871.pdf
# https://adviser.scottishwidows.co.uk//assets/literature/docs/54285.pdf
# https://adviser.scottishwidows.co.uk//assets/literature/docs/E995.pdf
# https://adviser.scottishwidows.co.uk//assets/literature/docs/55003.pdf
# https://adviser.scottishwidows.co.uk//assets/literature/docs/56890.pdf
# https://adviser.scottishwidows.co.uk//assets/literature/docs/47940.pdf
# https://adviser.scottishwidows.co.uk//assets/literature/docs/26261.pdf
# https://adviser.scottishwidows.co.uk//assets/literature/docs/56363.pdf
# https://adviser.scottishwidows.co.uk//assets/literature/docs/45770IG.pdf
# https://adviser.scottishwidows.co.uk//assets/literature/docs/EX1974.pdf
# https://adviser.scottishwidows.co.uk//assets/literature/docs/24576.pdf
# https://adviser.scottishwidows.co.uk//assets/literature/docs/28643.pdf
# https://adviser.scottishwidows.co.uk//assets/literature/docs/35771.pdf
# https://adviser.scottishwidows.co.uk//assets/literature/docs/52034.pdf
# https://adviser.scottishwidows.co.uk//assets/literature/docs/E391.pdf
# https://adviser.scottishwidows.co.uk//assets/literature/docs/EX058.pdf
# https://adviser.scottishwidows.co.uk//assets/literature/docs/E606.pdf
# https://adviser.scottishwidows.co.uk//assets/literature/docs/EX1285.pdf
# https://adviser.scottishwidows.co.uk//assets/literature/docs/EX2081.pdf
# https://adviser.scottishwidows.co.uk//assets/literature/docs/60255.pdf
# https://adviser.scottishwidows.co.uk//assets/literature/docs/44620.pdf
# https://adviser.scottishwidows.co.uk//assets/literature/docs/48778.pdf
# https://adviser.scottishwidows.co.uk//assets/literature/docs/56690.pdf
# https://adviser.scottishwidows.co.uk//assets/literature/docs/36357a.pdf
# https://adviser.scottishwidows.co.uk//assets/literature/docs/51262.pdf
# https://adviser.scottishwidows.co.uk//assets/literature/docs/56779.pdf
# https://adviser.scottishwidows.co.uk//assets/literature/docs/28724A.pdf
# https://adviser.scottishwidows.co.uk//assets/literature/docs/51290.pdf
# https://adviser.scottishwidows.co.uk//assets/literature/docs/25565.pdf
# https://adviser.scottishwidows.co.uk//assets/literature/docs/48432.pdf
# https://adviser.scottishwidows.co.uk//assets/literature/docs/60117.pdf
# https://adviser.scottishwidows.co.uk//assets/literature/docs/47122AGEN.pdf
# https://adviser.scottishwidows.co.uk//assets/literature/docs/1_339183-10.pdf
# https://adviser.scottishwidows.co.uk//assets/literature/docs/44623.pdf
# https://adviser.scottishwidows.co.uk//assets/literature/docs/44622.pdf
# https://adviser.scottishwidows.co.uk//assets/literature/docs/22953.pdf
# https://adviser.scottishwidows.co.uk//assets/literature/docs/60039.pdf
# https://adviser.scottishwidows.co.uk//assets/literature/docs/56412.pdf
# https://adviser.scottishwidows.co.uk//assets/literature/docs/27398.pdf
# https://adviser.scottishwidows.co.uk//assets/literature/docs/24917.pdf
# https://adviser.scottishwidows.co.uk//assets/literature/docs/46718c.pdf
# https://adviser.scottishwidows.co.uk//assets/literature/docs/26686.pdf
# https://adviser.scottishwidows.co.uk//assets/literature/docs/35139.pdf
# https://adviser.scottishwidows.co.uk//assets/literature/docs/1_339182-1.pdf
# https://adviser.scottishwidows.co.uk//assets/literature/docs/27253.pdf
# https://adviser.scottishwidows.co.uk//assets/literature/docs/27254.pdf
# https://adviser.scottishwidows.co.uk//assets/literature/docs/56715.pdf
# https://adviser.scottishwidows.co.uk//assets/literature/docs/55126.pdf
# https://adviser.scottishwidows.co.uk//assets/literature/docs/24850.pdf
# https://adviser.scottishwidows.co.uk//assets/literature/docs/52125.pdf
# https://adviser.scottishwidows.co.uk//assets/literature/docs/60873.pdf
# https://adviser.scottishwidows.co.uk//assets/literature/docs/60734.pdf
# https://adviser.scottishwidows.co.uk//assets/literature/docs/45816.pdf
# https://adviser.scottishwidows.co.uk//assets/literature/docs/47787.pdf
# https://adviser.scottishwidows.co.uk//assets/literature/docs/56797.pdf
# https://adviser.scottishwidows.co.uk//assets/literature/docs/47786.pdf
# https://adviser.scottishwidows.co.uk//assets/literature/docs/E1141.pdf
# https://adviser.scottishwidows.co.uk//assets/literature/docs/EX2118.pdf
# https://adviser.scottishwidows.co.uk//assets/literature/docs/testdocument.pdf
# https://adviser.scottishwidows.co.uk//assets/literature/docs/56735A.pdf
# https://adviser.scottishwidows.co.uk//assets/literature/docs/ESA1807.pdf
# https://adviser.scottishwidows.co.uk//assets/literature/docs/128434SW.pdf
# https://adviser.scottishwidows.co.uk//assets/literature/docs/EX2521.pdf
# https://adviser.scottishwidows.co.uk//assets/literature/docs/SW58059.pdf
# https://adviser.scottishwidows.co.uk//assets/literature/docs/SA1806.pdf
# https://adviser.scottishwidows.co.uk//assets/literature/docs/EX2656.pdf
# https://adviser.scottishwidows.co.uk//assets/literature/docs/150716Principal.pdf
# https://adviser.scottishwidows.co.uk//assets/literature/docs/41426.pdf
# https://adviser.scottishwidows.co.uk//assets/literature/docs/EX679a.pdf
# https://adviser.scottishwidows.co.uk//assets/literature/docs/53933.pdf
# https://adviser.scottishwidows.co.uk//assets/literature/docs/49970.pdf
# https://adviser.scottishwidows.co.uk//assets/literature/docs/26625.pdf
# https://adviser.scottishwidows.co.uk//assets/literature/docs/51004.pdf
# https://adviser.scottishwidows.co.uk//assets/literature/docs/E1546.pdf
# https://adviser.scottishwidows.co.uk//assets/literature/docs/56188.pdf
# https://adviser.scottishwidows.co.uk//assets/literature/docs/56376.pdf
# https://adviser.scottishwidows.co.uk//assets/literature/docs/E1287.pdf
# https://adviser.scottishwidows.co.uk//assets/literature/docs/56494.pdf
# https://adviser.scottishwidows.co.uk//assets/literature/docs/25361.pdf
# https://adviser.scottishwidows.co.uk//assets/literature/docs/44146.pdf
# https://adviser.scottishwidows.co.uk//assets/literature/docs/SW56316.pdf
# https://adviser.scottishwidows.co.uk//assets/literature/docs/56191.pdf
# https://adviser.scottishwidows.co.uk//assets/literature/docs/56193.pdf
# https://adviser.scottishwidows.co.uk//assets/literature/docs/56192.pdf
# https://adviser.scottishwidows.co.uk//assets/literature/docs/56449.pdf
# https://adviser.scottishwidows.co.uk//assets/literature/docs/EX2520.pdf
# https://adviser.scottishwidows.co.uk//assets/literature/docs/45981.pdf
# https://adviser.scottishwidows.co.uk//assets/literature/docs/36357.pdf
# https://adviser.scottishwidows.co.uk//assets/literature/docs/41622.pdf
# https://adviser.scottishwidows.co.uk//assets/literature/docs/55913.pdf
# https://adviser.scottishwidows.co.uk//assets/literature/docs/56063.pdf
# https://adviser.scottishwidows.co.uk//assets/literature/docs/EX1769.pdf
# https://adviser.scottishwidows.co.uk//assets/literature/docs/44010.pdf
# https://adviser.scottishwidows.co.uk//assets/literature/docs/60410.pdf
# https://adviser.scottishwidows.co.uk//assets/literature/docs/56783.pdf
# https://adviser.scottishwidows.co.uk//assets/literature/docs/24683.pdf
# https://adviser.scottishwidows.co.uk//assets/literature/docs/56635.pdf
# https://adviser.scottishwidows.co.uk//assets/literature/docs/48569.pdf
# https://adviser.scottishwidows.co.uk//assets/literature/docs/16633.pdf
# https://adviser.scottishwidows.co.uk//assets/literature/docs/52483.pdf
# https://adviser.scottishwidows.co.uk//assets/literature/docs/SW58004A.pdf
# https://adviser.scottishwidows.co.uk//assets/literature/docs/16540.pdf
# https://adviser.scottishwidows.co.uk//assets/literature/docs/55430.pdf
# https://adviser.scottishwidows.co.uk//assets/literature/docs/37180.pdf
# https://adviser.scottishwidows.co.uk//assets/literature/docs/43982b.pdf
# https://adviser.scottishwidows.co.uk//assets/literature/docs/1_6226618-9.pdf
# https://adviser.scottishwidows.co.uk//assets/literature/docs/EX2083.pdf
# https://adviser.scottishwidows.co.uk//assets/literature/docs/28700.pdf
# https://adviser.scottishwidows.co.uk//assets/literature/docs/E440.pdf
# https://adviser.scottishwidows.co.uk//assets/literature/docs/36327.pdf
# https://adviser.scottishwidows.co.uk//assets/literature/docs/48894.pdf
# https://adviser.scottishwidows.co.uk//assets/literature/docs/EX1770.pdf
# https://adviser.scottishwidows.co.uk//assets/literature/docs/44423.pdf
# https://adviser.scottishwidows.co.uk//assets/literature/docs/60028.pdf
# https://adviser.scottishwidows.co.uk//assets/literature/docs/60880.pdf
# https://adviser.scottishwidows.co.uk//assets/literature/docs/16981.pdf
# https://adviser.scottishwidows.co.uk//assets/literature/docs/14078.pdf
# https://adviser.scottishwidows.co.uk//assets/literature/docs/1_337849-10.pdf
# https://adviser.scottishwidows.co.uk//assets/literature/docs/E434.pdf
# https://adviser.scottishwidows.co.uk//assets/literature/docs/37127.pdf
# https://adviser.scottishwidows.co.uk//assets/literature/docs/56036.pdf
# https://adviser.scottishwidows.co.uk//assets/literature/docs/expirypdftest.pdf
# https://adviser.scottishwidows.co.uk//assets/literature/docs/56793.pdf
# https://adviser.scottishwidows.co.uk//assets/literature/docs/24650.pdf
# https://adviser.scottishwidows.co.uk//assets/literature/docs/55119.pdf
# https://adviser.scottishwidows.co.uk//assets/literature/docs/31870.pdf
# https://adviser.scottishwidows.co.uk//assets/literature/docs/E390.pdf
# https://adviser.scottishwidows.co.uk//assets/literature/docs/EX1813.pdf
# https://adviser.scottishwidows.co.uk//assets/literature/docs/ppfm.pdf
# https://adviser.scottishwidows.co.uk//assets/literature/docs/55038.pdf
# https://adviser.scottishwidows.co.uk//assets/literature/docs/35816.pdf
# https://adviser.scottishwidows.co.uk//assets/literature/docs/56190.pdf
# https://adviser.scottishwidows.co.uk//assets/literature/docs/56189.pdf
# https://adviser.scottishwidows.co.uk//assets/literature/docs/55451.pdf
# https://adviser.scottishwidows.co.uk//assets/literature/docs/55503.pdf
# https://adviser.scottishwidows.co.uk//assets/literature/docs/44487.pdf
# https://adviser.scottishwidows.co.uk//assets/literature/docs/19145.pdf
# https://adviser.scottishwidows.co.uk//assets/literature/docs/x1332.pdf
# https://adviser.scottishwidows.co.uk//assets/literature/docs/x1678.pdf
# https://adviser.scottishwidows.co.uk//assets/literature/docs/52885.pdf
# https://adviser.scottishwidows.co.uk//assets/literature/docs/1_3390182-10.pdf
# https://adviser.scottishwidows.co.uk//assets/literature/docs/45422.pdf
# https://adviser.scottishwidows.co.uk//assets/literature/docs/56358.pdf
# https://adviser.scottishwidows.co.uk//assets/literature/docs/60439.pdf
# https://adviser.scottishwidows.co.uk//assets/literature/docs/56357.pdf
# https://adviser.scottishwidows.co.uk//assets/literature/docs/61107.pdf
# https://adviser.scottishwidows.co.uk//assets/literature/docs/60431.pdf
# https://adviser.scottishwidows.co.uk//assets/literature/docs/55197.pdf
# https://adviser.scottishwidows.co.uk//assets/literature/docs/1_339151-1.pdf
# https://adviser.scottishwidows.co.uk//assets/literature/docs/EX816.pdf
# https://adviser.scottishwidows.co.uk//assets/literature/docs/EX820.pdf
# https://adviser.scottishwidows.co.uk//assets/literature/docs/1_337850-3.pdf
# https://adviser.scottishwidows.co.uk//assets/literature/docs/EX1297.pdf
# https://adviser.scottishwidows.co.uk//assets/literature/docs/E304.pdf
# https://adviser.scottishwidows.co.uk//assets/literature/docs/52872.pdf
# https://adviser.scottishwidows.co.uk//assets/literature/docs/1_339762-1.pdf
# https://adviser.scottishwidows.co.uk//assets/literature/docs/60296.pdf
# https://adviser.scottishwidows.co.uk//assets/literature/docs/23470.pdf
# https://adviser.scottishwidows.co.uk//assets/literature/docs/14013.pdf
# https://adviser.scottishwidows.co.uk//assets/literature/docs/x679c.pdf
# https://adviser.scottishwidows.co.uk//assets/literature/docs/56337.pdf
# https://adviser.scottishwidows.co.uk//assets/literature/docs/56336.pdf
# https://adviser.scottishwidows.co.uk//assets/literature/docs/49390.pdf
# https://adviser.scottishwidows.co.uk//assets/literature/docs/55279.pdf
# https://adviser.scottishwidows.co.uk//assets/literature/docs/EX819.pdf
# https://adviser.scottishwidows.co.uk//assets/literature/docs/43536.pdf
# https://adviser.scottishwidows.co.uk//assets/literature/docs/EX815.pdf
# https://adviser.scottishwidows.co.uk//assets/literature/docs/EX168.pdf
# https://adviser.scottishwidows.co.uk//assets/literature/docs/EX813.pdf
# https://adviser.scottishwidows.co.uk//assets/literature/docs/56696.pdf
# https://adviser.scottishwidows.co.uk//assets/literature/docs/53932.pdf

# %%
def get_all_pdf_links(entry_page_url):
    """Extract all pdf links from an url and return a DataFrame with title and pdf url as columns"""
    
    response = requests.get(url=entry_page_url)
    soup = BeautifulSoup(response.content, "html.parser")

    download_links = soup.find_all(class_="title")
    
    df = pd.DataFrame([
        {"title": pdf_link.string.strip(), "url": "https://adviser.scottishwidows.co.uk" + pdf_link.get("href")} 
        for pdf_link in download_links 
    ])
    
    return df

# %%
pdf_urls_df = get_all_pdf_links(search_url)
pdf_urls_df.tail()
# Out:
#                                        title  \
# 218                 CPA (S1) Charges Leaflet
# 219  Scottish Widows Weekly Cash Fund Report
# 220                   PPA (S2) Charges sheet
# 221           Product charges - REA series 2
# 222      Halifax monthly plan charges - life
#
#                                                    url
# 218  https://adviser.scottishwidows.co.uk/assets/li...
# 219  https://adviser.scottishwidows.co.uk/assets/li...
# 220  https://adviser.scottishwidows.co.uk/assets/li...
# 221  https://adviser.scottishwidows.co.uk/assets/li...
# 222  https://adviser.scottishwidows.co.uk/assets/li...

# %%
pdf_urls_df.shape
# Out:
# (223, 2)

# %% [markdown]
# ### Validating the end points

# %%
def check_url_exist(url):
    """To check the url endpoint does exist"""
    
    response = requests.get(url=url)
    
    return response.status_code == requests.codes.ok

def clean_pdf_urls(urls_df):
    """To remove all the invalid urls from the urls_df"""
    
    exist = urls_df["url"].apply(check_url_exist) # ToDo: do it in parallel
    
    return urls_df.loc[exist]

def is_encrypted(pdf_url):
    response = requests.get(url=pdf_url)
    assert response.status_code == requests.codes.ok
    
    pdf_reader = PyPDF2.PdfReader( io.BytesIO(response.content) )

    return pdf_reader.is_encrypted

print(is_encrypted(pdf_url))

clean_pdf_urls(pdf_urls_df[0:10])
# Out:
# False
#                                                title  \
# 0         Deed of Appointment of Additional Trustees
# 1     Deed of Nomination and Retirement of Protector
# 2   Scottish Widows Protect – The illnesses we cover
# 3          ​​Scottish Widows Bank Premier Team Flyer
# 4                                   FSCS SWUTM flyer
# 5  Your guide to making withdrawals from your Col...
# 6              HBOS Important Notes For Applications
# 7                         KFD COMPANY PENSIONBUILDER
# 8                                 GSHP Joining Guide
# 9                    ​​HIFML value assessment report
#
#                                                  url
# 0  https://adviser.scottishwidows.co.uk/assets/li...
# 1  https://adviser.scottishwidows.co.uk/assets/li...
# 2  https://adviser.scottishwidows.co.uk/assets/li...
# 3  https://adviser.scottishwidows.co.uk/assets/li...
# 4  https://adviser.scottishwidows.co.uk/assets/li...
# 5  https://adviser.scottishwidows.co.uk/assets/li...
# 6  https://adviser.scottishwidows.co.uk/assets/li...
# 7  https://adviser.scottishwidows.co.uk/assets/li...
# 8  https://adviser.scottishwidows.co.uk/assets/li...
# 9  https://adviser.scottishwidows.co.uk/assets/li...

# %%
pdf_urls_df[0:10].loc[lambda _s: _s.url.apply(check_url_exist)]
# Out:
#                                                title  \
# 0         Deed of Appointment of Additional Trustees
# 1     Deed of Nomination and Retirement of Protector
# 2   Scottish Widows Protect – The illnesses we cover
# 3          ​​Scottish Widows Bank Premier Team Flyer
# 4                                   FSCS SWUTM flyer
# 5  Your guide to making withdrawals from your Col...
# 6              HBOS Important Notes For Applications
# 7                         KFD COMPANY PENSIONBUILDER
# 8                                 GSHP Joining Guide
# 9                    ​​HIFML value assessment report
#
#                                                  url
# 0  https://adviser.scottishwidows.co.uk/assets/li...
# 1  https://adviser.scottishwidows.co.uk/assets/li...
# 2  https://adviser.scottishwidows.co.uk/assets/li...
# 3  https://adviser.scottishwidows.co.uk/assets/li...
# 4  https://adviser.scottishwidows.co.uk/assets/li...
# 5  https://adviser.scottishwidows.co.uk/assets/li...
# 6  https://adviser.scottishwidows.co.uk/assets/li...
# 7  https://adviser.scottishwidows.co.uk/assets/li...
# 8  https://adviser.scottishwidows.co.uk/assets/li...
# 9  https://adviser.scottishwidows.co.uk/assets/li...

# %%
#%%timeit -n 1 -r 1

df1 = clean_pdf_urls(pdf_urls_df)

(pdf_urls_df.shape, df1.shape)
# Out:
# ((223, 2), (219, 2))

# %%
#%%timeit -n 1 -r 1

df2 = df1.url.apply(is_encrypted)

df2.shape
# Out:
# (219,)

# %%
# some files are encrypted
df1.loc[df2]

# %% [markdown]
# ## Collect all the PDF Contents

# %%
for index, row in pdf_urls_df.iloc[0:2].iterrows():
    print(f"-------------{index}----")
    print(get_pdf_pages(row.url).assign(title=row.title))
# Out:
# -------------0----
#    page_number                                          page_text  \
# 0            1  OF ADDITIONAL TRUSTEES\nfor use with the Absol...
# 1            2  1WHAT THIS FORM IS FOR\nYou have been provided...
# 2            3  21. DEED OF APPOINTMENT\nThis Deed of Appointm...
# 3            4  32. BACKGROUND\n2.1 This deed is supplemental ...
# 4            5  44. DATA PRIVACY NOTICE (CONTINUED)\n• from an...
# 5            6  55. SIGNATURES\nThis and the preceding pages a...
# 6            7  65. SIGNATURES (CONTINUED)\n1st Additional tru...
# 7            8  5. SIGNATURES (CONTINUED)\n2nd Additional trus...
#
#                                         title
# 0  Deed of Appointment of Additional Trustees
# 1  Deed of Appointment of Additional Trustees
# 2  Deed of Appointment of Additional Trustees
# 3  Deed of Appointment of Additional Trustees
# 4  Deed of Appointment of Additional Trustees
# 5  Deed of Appointment of Additional Trustees
# 6  Deed of Appointment of Additional Trustees
# 7  Deed of Appointment of Additional Trustees
# -------------1----
#    page_number                                          page_text  \
# 0            1       AND RETIREMENT OF PROTECTORDEED OFNOMINATION
# 1            2  2FOR THE SOLE PROTECTOR OF AN EXISTING TRUST W...
# 2            3  3This DEED is made on (DD MM YYYY)  \nBETWEEN\...
# 3            4  4WHEREAS\n1. The Appointor is the present prot...
# 4            5  5SIGNED and DELIVERED AS A DEED by the said\nN...
# 5            6  SIGNED and DELIVERED AS A DEED by the said\nNa...
#
#                                             title
# 0  Deed of Nomination and Retirement of Protector
# 1  Deed of Nomination and Retirement of Protector
# 2  Deed of Nomination and Retirement of Protector
# 3  Deed of Nomination and Retirement of Protector
# 4  Deed of Nomination and Retirement of Protector
# 5  Deed of Nomination and Retirement of Protector

# %%
df = pd.concat(
    [
        get_pdf_pages(row.url).assign(title=row.title)
        for index, row in pdf_urls_df.iloc[0:10].iterrows() if check_url_exist(row.url)
    ],
    axis=0, 
    ignore_index=True)

print(df.shape)
df.head()
# Out:
# (84, 3)
#    page_number                                          page_text  \
# 0            1  OF ADDITIONAL TRUSTEES\nfor use with the Absol...
# 1            2  1WHAT THIS FORM IS FOR\nYou have been provided...
# 2            3  21. DEED OF APPOINTMENT\nThis Deed of Appointm...
# 3            4  32. BACKGROUND\n2.1 This deed is supplemental ...
# 4            5  44. DATA PRIVACY NOTICE (CONTINUED)\n• from an...
#
#                                         title
# 0  Deed of Appointment of Additional Trustees
# 1  Deed of Appointment of Additional Trustees
# 2  Deed of Appointment of Additional Trustees
# 3  Deed of Appointment of Additional Trustees
# 4  Deed of Appointment of Additional Trustees

# %%
df.tail()
# Out:
#     page_number                                          page_text  \
# 79           18  18\nRetail Funds\n • • • • • • • • • • • • • •...
# 80           19  19\nSophie O’Connor – \nIndependent AFM Chair ...
# 81           20  20\nActive investing\nActive investing takes a...
# 82           21  21\nIndex tracking\nAn index fund is construct...
# 83           22  60039 (11/21)HBOS Investment Fund Managers Lim...
#
#                               title
# 79  ​​HIFML value assessment report
# 80  ​​HIFML value assessment report
# 81  ​​HIFML value assessment report
# 82  ​​HIFML value assessment report
# 83  ​​HIFML value assessment report

# %%
#%%timeit -n 1 -r 1 # about 3.5 minutes to run
import time

start = time.time()
guides_df = pd.concat(
    [
        get_pdf_pages(row.url).assign(title=row.title)
        for index, row in pdf_urls_df.iterrows() if check_url_exist(row.url)
    ],
    axis=0, 
    ignore_index=True)
print(time.time() - start)

print(guides_df.shape)

guides_df.tail()
# Out:
# 144.84666967391968
# (2900, 3)
#       page_number                                          page_text  \
# 2895            1  The following charges apply to your account fr...
# 2896            2  Where applicable, the charge for with-profits ...
# 2897            1  Policy charge (also known as a plan charge)\nT...
# 2898            2  Additional fund charge\nFor an initial period ...
# 2899            1  Monthly plan  \ncharges for 2024.\nThe followi...
#
#                                     title
# 2895               PPA (S2) Charges sheet
# 2896               PPA (S2) Charges sheet
# 2897       Product charges - REA series 2
# 2898       Product charges - REA series 2
# 2899  Halifax monthly plan charges - life

# %%
guides_df.memory_usage(deep=True)
# Out:
# Index               128
# page_number       23200
# page_text      10408098
# title            308960
# dtype: int64

# %%
all_guides_file = "scottish_widows_all_guides.pq"

# %%
guides_df.to_parquet(all_guides_file)

# %%
os.stat(all_guides_file)
# Out:
# os.stat_result(st_mode=33188, st_ino=1048781, st_dev=2064, st_nlink=1, st_uid=1001, st_gid=1002, st_size=2535292, st_atime=1706190879, st_mtime=1706190879, st_ctime=1706190879)

# %%
df2 = pd.read_parquet(all_guides_file)
df2.head()
# Out:
#    page_number                                          page_text  \
# 0            1  OF ADDITIONAL TRUSTEES\nfor use with the Absol...
# 1            2  1WHAT THIS FORM IS FOR\nYou have been provided...
# 2            3  21. DEED OF APPOINTMENT\nThis Deed of Appointm...
# 3            4  32. BACKGROUND\n2.1 This deed is supplemental ...
# 4            5  44. DATA PRIVACY NOTICE (CONTINUED)\n• from an...
#
#                                         title
# 0  Deed of Appointment of Additional Trustees
# 1  Deed of Appointment of Additional Trustees
# 2  Deed of Appointment of Additional Trustees
# 3  Deed of Appointment of Additional Trustees
# 4  Deed of Appointment of Additional Trustees

# %%
df2.shape
# Out:
# (2900, 3)

# %%
pd.testing.assert_frame_equal(df2, guides_df)

# %% [markdown]
# ## Scratch

# %%
#try_url = "https://adviser.scottishwidows.co.uk//assets/literature/docs/42365.pdf"
#try_url = "https://adviser.scottishwidows.co.uk//assets/literature/docs/fsaSWplcFSAReturn2007.pdf"
#try_url = "https://adviser.scottishwidows.co.uk//assets/literature/docs/27316.pdf"
#try_url = "https://adviser.scottishwidows.co.uk//assets/literature/docs/28742a.pdf"
#try_url = "https://adviser.scottishwidows.co.uk//assets/literature/docs/56241.pdf"

#try_url = "https://adviser.scottishwidows.co.uk/assets/literature/docs/52125.pdf"
#try_url = "https://adviser.scottishwidows.co.uk/assets/literature/docs/56696.pdf"
try_url = "https://adviser.scottishwidows.co.uk/assets/literature/docs/56036.pdf"
    
get_pdf_pages(try_url)
